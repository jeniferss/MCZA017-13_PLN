# %% [markdown]
# <a href="https://colab.research.google.com/github/jeniferss/MCZA017-13_PLN/blob/main/2025_q3_pln_projeto_final_first_results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Processamento de Linguagem Natural [2025-Q3]**
# Prof. Alexandre Donizeti Alves

# %% [markdown]
# ### **PROJETO PRÁTICO** [LangChain + Grandes Modelos de Linguagem]

# %% [markdown]
# O **PROJETO PRÁTICO** deve ser feito utilizando o **Google Colab** com uma conta sua vinculada ao Gmail. O link do seu notebook armazenado no Google Drive e o link de um repositório no GitHub devem ser enviados usando o seguinte formulário:
#
# > https://forms.gle/D4gLqP1iGgyn2hbH8
#
#
# **IMPORTANTE**: A submissão deve ser feita até o dia **07/12 (domingo)** APENAS POR UM INTEGRANTE DA EQUIPE, até às 23h59. Por favor, lembre-se de dar permissão de ACESSO IRRESTRITO para o professor da disciplina.

# %% [markdown]
# ### **EQUIPE**
#
# ---

# %% [markdown]
# **POR FAVOR, PREENCHER OS INTEGRANDES DA SUA EQUIPE:**
#
#
# **Integrante 01:**
#
# `JENIFER SOARES SOUZA           11202020219`
#
# **Integrante 02:**
#
# `JUAN PABLO MORENO OLIVEIRA     11202131494`

# %% [markdown]
# ### **GRANDE MODELO DE LINGUAGEM (*Large Language Model - LLM*)**
#
# ---

# %% [markdown]
# Cada equipe deve selecionar um Grande Modelo de Linguagem (*Large Language Model - LMM*).

# %% [markdown]
# Por favor, informe os dados do LLM selecionada:
#
# >
#
#
# **LLM**: GPT-4.1 mini ou gemini-2.5-flash
#
# >
#
# **Link para a documentação oficial**: https://openai.com/index/gpt-4-1/ ou https://docs.cloud.google.com/vertex-ai/generative-ai/docs/models/gemini/2-5-flash?hl=pt-br

# %% [markdown]
# ### **API (Opcional)**
# ---

# %% [markdown]
# Por favor, informe os dados da API selecionada:
#
# **API**:Gutendex
#
# **Site oficial**:https://gutendex.com/
#
# **Link para a documentação oficial**:https://gutendex.com/ (na homepage)

# %% [markdown]
# ### **DESCRIÇÃO**
# ---

# %% [markdown]
# Implementar um `notebook` no `Google Colab` que faça uso do framework **`LangChain`** (obrigatório) e de um **LLM** aplicando, no mínimo, DUAS técnicas de PLN. As técnicas podem ser aplicada em qualquer córpus obtido a partir de uma **API** ou a partir de uma página Web.
#
# O **LLM** e a **API** selecionados devem ser informados na seguinte planilha:
#
# > https://docs.google.com/spreadsheets/d/1iIUZcwnywO7RuF6VEJ8Rx9NDT1cwteyvsnkhYr0NWtU/edit?usp=sharing
#
# >
# As seguintes técnicas de PLN podem ser usadas:
#
# *   Correção Gramatical
# *   Classificação de Textos
# *   Análise de Sentimentos
# *   Detecção de Emoções
# *   Extração de Palavras-chave
# *   Tradução de Textos
# *   Sumarização de Textos
# *   Similaridade de Textos
# *   Reconhecimento de Entidades Nomeadas
# *   Sistemas de Perguntas e Respostas
# >
#
# **IMPORTANTE:** É obrigatório usar o e-mail da UFABC.

# %% [markdown]
# ### **CRITÉRIOS DE AVALIAÇÃO**
# ---

# %% [markdown]
# Serão considerados como critérios de avaliação os seguintes pontos:
#
# * Uso do framework **`LangChain`**.
#
# * Escolha e uso de um **LLM**.
#
# * Escolha e uso de uma **API** ou **Página Web**.
#
# * Projeto disponível no Github.
#
# * Apresentação (5 a 10 minutos).
#
# * Criatividade no uso do framework **`LangChain`** em conjunto com o **LLM** e a **API**.

# %% [markdown]
# **IMPORTANTE**: todo o código do notebook deve ser executado. Código sem execução não será considerado.

# %% [markdown]
# ### **IMPLEMENTAÇÃO**
# ---

# %% [markdown]
# Neste trabalho, utilizamos como fonte de dados o [Projeto Gutenberg](https://www.gutenberg.org/about/), que disponibiliza obras literárias em domínio público. A partir desse acervo, selecionamos quatro livros brasileiros de interesse para análise — *Dom Casmurro*, *O Cortiço* e *Quincas Borba*. Para integrá-los ao pipeline, realizamos o mapeamento manual de seus respectivos *IDs* no catálogo e utilizamos a API [Gutendex](https://gutendex.com/) para recuperar metadados essenciais, incluindo as URLs que fornecem o texto completo em formato **.txt**.

# %% [markdown]
# #### Instalação de bibliotecas

# %%
# !pip install -U "langchain[google-genai]"
# Out:
# Requirement already satisfied: langchain[google-genai] in /usr/local/lib/python3.12/dist-packages (1.0.8)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.6 in /usr/local/lib/python3.12/dist-packages (from langchain[google-genai]) (1.1.0)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in /usr/local/lib/python3.12/dist-packages (from langchain[google-genai]) (1.0.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain[google-genai]) (2.11.10)
# Requirement already satisfied: langchain-google-genai in /usr/local/lib/python3.12/dist-packages (from langchain[google-genai]) (3.1.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.0.6->langchain[google-genai]) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.0.6->langchain[google-genai]) (0.4.43)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.0.6->langchain[google-genai]) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.0.6->langchain[google-genai]) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.0.6->langchain[google-genai]) (8.5.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.0.6->langchain[google-genai]) (4.15.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.2->langchain[google-genai]) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.2->langchain[google-genai]) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.2->langchain[google-genai]) (0.2.9)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.2->langchain[google-genai]) (3.6.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain[google-genai]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain[google-genai]) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain[google-genai]) (0.4.2)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-google-genai->langchain[google-genai]) (1.2.0)
# Requirement already satisfied: google-ai-generativelanguage<1.0.0,>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from langchain-google-genai->langchain[google-genai]) (0.9.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai->langchain[google-genai]) (2.28.1)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in /usr/local/lib/python3.12/dist-packages (from google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai->langchain[google-genai]) (2.38.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai->langchain[google-genai]) (1.76.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai->langchain[google-genai]) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in /usr/local/lib/python3.12/dist-packages (from google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai->langchain[google-genai]) (5.29.5)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.6->langchain[google-genai]) (3.0.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain[google-genai]) (1.12.0)
# Requirement already satisfied: httpx>=0.25.2 in /usr/local/lib/python3.12/dist-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain[google-genai]) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in /usr/local/lib/python3.12/dist-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain[google-genai]) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.6->langchain[google-genai]) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.6->langchain[google-genai]) (2.32.4)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.6->langchain[google-genai]) (0.25.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai->langchain[google-genai]) (1.72.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai->langchain[google-genai]) (1.71.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai->langchain[google-genai]) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai->langchain[google-genai]) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai->langchain[google-genai]) (4.9.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain[google-genai]) (4.11.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain[google-genai]) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain[google-genai]) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain[google-genai]) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain[google-genai]) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.6->langchain[google-genai]) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.6->langchain[google-genai]) (2.5.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai->langchain[google-genai]) (0.6.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain[google-genai]) (1.3.1)

# %% [markdown]
# #### Importação de bibliotecas

# %%
import csv
import json
import json
import os
import pandas as pd
import pandas as pd
import re
import requests
import spacy
import unicodedata
from google.colab import userdata
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate
from langchain_core.runnables import RunnableLambda, RunnableMap
from langchain_google_genai import ChatGoogleGenerativeAI
from pydantic import BaseModel, HttpUrl
from spacy.lang.en.stop_words import STOP_WORDS as EN_STOPWORDS
from time import sleep
from typing import List, Optional, Dict, Set

# %% [markdown]
# #### Definição dos modelos de dados

# %%
class Person(BaseModel):
    name: str
    birth_year: Optional[int] = None
    death_year: Optional[int] = None


class BookMetadataInput(BaseModel):
    id: int
    title: str
    authors: List[Person]
    summaries: List[str] = []
    editors: List[Person] = []
    translators: List[Person] = []
    subjects: List[str] = []
    bookshelves: List[str] = []
    languages: List[str] = []
    copyright: Optional[bool] = None
    media_type: Optional[str] = None
    formats: Dict[str, HttpUrl]
    download_count: int


class BookMetadataOutput(BaseModel):
    title: str
    authors: List[Person]
    summaries: List[str] = []
    subjects: List[str] = []
    characters: List[str] = []
    languages: List[str] = []
    copyright: Optional[bool] = None
    media_type: Optional[str] = None
    text_url: HttpUrl


class CharacterLLMInput(BaseModel):
    book: BookMetadataOutput
    character_name: str
    snippets: Dict[int, str]

# %% [markdown]
# #### Definição de funções auxiliares

# %%
def _normalize_name(name: str) -> str:
    name = name.strip().strip('"').strip("'").strip()
    name = re.sub(r"[’'´`]+s$", "", name)
    return name


def _name_tokens(name: str) -> Set[str]:
    return {t for t in re.split(r"\s+", name) if t}


def _author_token_set(authors) -> Set[str]:
    tokens = set()
    for a in authors:
        norm = _normalize_name(a.name.replace(",", " "))
        tokens.update(_name_tokens(norm))
    return tokens


def _is_stop_candidate(token_text: str) -> bool:
    if not token_text:
        return True
    if token_text.lower() in EN_STOPWORDS:
        return True
    if len(token_text) <= 2:
        return True
    return False


def _strip_accents(s: str) -> str:
    nfkd = unicodedata.normalize("NFD", s)
    return "".join(ch for ch in nfkd if unicodedata.category(ch) != "Mn")


def _split_paragraphs(text: str) -> List[str]:
    raw_paragraphs = re.split(r"\n\s*\n", text)
    return [p.strip() for p in raw_paragraphs if p.strip()]


def extract_book_metadata(book: int) -> BookMetadataInput:
    response = requests.get(f"https://gutendex.com/books/{book}")
    response.raise_for_status()

    gutendex = BookMetadataInput.model_validate(response.json())
    return gutendex


def extract_character_names(book) -> List[str]:
    text = " ".join(book.summaries or [])
    doc = nlp(text)

    author_tokens = _author_token_set(book.authors)
    raw_candidates: Set[str] = set()

    for ent in doc.ents:
        if ent.label_ != "PERSON":
            continue

        name = _normalize_name(ent.text)
        if not name:
            continue

        tokens = _name_tokens(name)
        if not tokens:
            continue

        if tokens.issubset(author_tokens):
            continue

        raw_candidates.add(name)

    return sorted(raw_candidates)


def enrich_books_with_characters(book: BookMetadataInput) -> BookMetadataOutput:
    return BookMetadataOutput(
        authors=book.authors,
        title=book.title,
        summaries=book.summaries,
        subjects=book.subjects,
        characters=extract_character_names(book),
        text_url=book.formats['text/plain; charset=us-ascii']
    )


def find_relevant_paragraphs(
        paragraphs: List[str],
        character_name: str,
        window: int = 1,
        min_length: int = 80,
) -> List[str]:
    max_snippets_in_prompt = 20

    name_norm = _strip_accents(character_name).lower()
    pattern = re.compile(rf"\b{re.escape(name_norm)}\b")

    hit_indices: List[int] = []
    for i, p in enumerate(paragraphs):
        p_norm = _strip_accents(p).lower()
        if pattern.search(p_norm):
            hit_indices.append(i)

    if not hit_indices:
        return {}

    selected_indices: List[int] = []
    seen: Set[int] = set()

    for idx in hit_indices:
        start = max(0, idx - window)
        end = min(len(paragraphs), idx + window + 1)

        for j in range(start, end):
            if j not in seen:
                seen.add(j)
                selected_indices.append(j)

    selected_indices.sort()
    return {
        i: paragraphs[i].replace("\r\n", "\n").replace("\r", "")
        for i in selected_indices[:max_snippets_in_prompt] if len(paragraphs[i].strip()) >= min_length
    }


def build_character_llm_input(
        book_output: BookMetadataOutput,
        character_name: str,
        window: int = 1
) -> CharacterLLMInput:
    response = requests.get(book_output.text_url)
    response.raise_for_status()

    paragraphs = _split_paragraphs(response.text)
    snippets = find_relevant_paragraphs(
        paragraphs,
        character_name=character_name,
        window=window
    )

    return CharacterLLMInput(
        book=book_output,
        character_name=character_name,
        snippets=snippets
    )


def build_prompt_from_context(ctx: CharacterLLMInput) -> str:
    data = json.dumps({
        "metadados_livro": {
            "titulo": ctx.book.title,
            "autores": [a.model_dump() for a in ctx.book.authors],
            "assuntos": ctx.book.subjects,
            "personagens_detectados_no_resumo": ctx.book.characters
        },
        "personagem_alvo": {
            "nome": ctx.character_name
        },
        "trechos_texto": ctx.snippets
    }, ensure_ascii=False)
    return data


def process_book_characters(book: BookMetadataOutput) -> List[dict]:
    results: List[dict] = []

    for character_name in book.characters:
        try:
            if not character_name.strip:
                continue

            print(f"\n\nProcessando {character_name} para o livro {book.title}")
            ctx = build_character_llm_input(
                book_output=book,
                character_name=character_name,
                window=1,
            )

            if not book.characters:
                print(f"Nenhum personagem encontrado para o livro {book.title}")
                continue

            if not ctx.snippets:
                print(f"Nenhum parágrafo encontrado personagem de nome {character_name} encontrado para o livro {book.title}")

            prompt_text = build_prompt_from_context(ctx)
            llm_output = trait_chain.invoke({"texto": prompt_text})

            results.append(
                {
                    "character_name": character_name,
                    "character_context": ctx,
                    "llm_output": llm_output,
                }
            )

            build_row_from_result(ctx, llm_output)
            sleep(1)

        except Exception as error:
            print("Falha ao extrair dados do personagem", str(error))

    return results


def build_row_from_result(ctx: CharacterLLMInput, llm_output: str) -> List[dict]:
    book = ctx.book

    authors_json = json.dumps([a.model_dump() for a in book.authors], ensure_ascii=False)
    summaries_json = json.dumps(book.summaries, ensure_ascii=False)
    subjects_json = json.dumps(book.subjects, ensure_ascii=False)
    characters_json = json.dumps(book.characters, ensure_ascii=False)

    cleaned = re.sub(r"^```(\w+)?", "", llm_output.strip())
    cleaned = re.sub(r"```$", "", cleaned).strip()

    inferences = json.loads(cleaned)["inferences"]
    resume = json.loads(cleaned)["resume"]

    results = []
    for inference in inferences:
        row = {
            "title": book.title,
            "authors": authors_json,
            "summaries": summaries_json,
            "subjects": subjects_json,
            "characters": characters_json,
            "text_url": book.text_url,
            "character_name": ctx.character_name,
            "character_resume": resume,
            "snippet": ctx.snippets.get(int(inference["id"])),
            "traits": json.dumps(inference["traits"], ensure_ascii=False),
        }

        append_row_to_csv(row)
        results.append(row)

    return results


def append_row_to_csv(row: dict, path: str = "characters_dataset.csv") -> None:
    file_exists = os.path.exists(path)

    with open(path, "a", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(f, fieldnames=row.keys())
        if not file_exists:
            writer.writeheader()
        writer.writerow(row)

# %% [markdown]
# #### Configuração para a pipeline

# %%
nlp = spacy.load("en_core_web_sm")

GOOGLE_API_KEY = userdata.get('GOOGLE_API_KEY')
print(f"\n\nGOOGLE_API_KEY está vazia." if GOOGLE_API_KEY is None else "")

llm_model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    google_api_key=GOOGLE_API_KEY,
    temperature=0.0,
)

trait_prompt = PromptTemplate(
    input_variables=["texto"],
    template=("""
        Você é um analista especializado em perfis de personagens literários. Com base EXCLUSIVAMENTE nos trechos fornecidos abaixo, produza um JSON com inferências de personalidade. Regras obrigatórias:
        - A saída deve conter apenas JSON. Não inclua explicações.
        - O JSON final deve ter exatamente as chaves:
        - "inferences": lista de objetos.
        - "resume": um resumo com NO MÁXIMO 200 caracteres EM PORTUGUÊS BARSILEIRO sobre quem é o personagem com base EM TODOS OS TRECHOS enviado no contexto como "trechos_texto".
        - Cada objeto dentro de "inferences" deve seguir esta estrutura:
        - "id": o mesmo id recebido na entrada, correspondente ao trecho analisado.
        - "traits": lista de adjetivos que descrevem a personalidade detectada NO TRECHO.
        - Você deve retirar apenas traits claramente justificáveis pelo trecho.
        - Se não houver traits relevantes, NÃO inclua esse item na lista "inferences".
        - Todos os adjetivos devem ser:
        - em PORTUGUÊS BRASILEIRO,
        - no gênero masculino,
        - escolhidos APENAS desta lista:
        astuto, inteligente, rabugento, sensível, misterioso, impulsivo, determinado, melancólico, orgulhoso, cínico, ingênuo, corajoso, leal, ambicioso, manipulador, compulsivo, vaidoso, inseguro, ciumento, observador, tímido, protetor, teimoso, irônico, frio, calculista, curioso, sonhador, dramático, solitário, pessimista, temperamental, independente, romântico, carismático, arrogante, gentil, questionador, sarcástico, bondoso, rigoroso, rebelde, racional, emocional, aventureiro, prudente, ético, manipulável, resiliente, confuso, audacioso, obediente, altruísta, egoísta, controlador, precavido, trabalhador, preguiçoso, perfeccionista, desorganizado, criativo, pragmático, rígido, metódico, procrastinador, desconfiado, dominador, generoso, esperançoso, focado, inovador, conservador, inconsequente, responsável, ansioso, mediador, inflexível, empático, exigente, submisso, autoritário.
        Contexto: \n {texto}
    """),
)

trait_chain = trait_prompt | llm_model | StrOutputParser()

# %% [markdown]
# #### Definição da pipeline

# %%
fetch_metadata_runnable = RunnableLambda(
    lambda inp: extract_book_metadata(inp["book_id"])
)

enrich_with_characters_runnable = RunnableLambda(
    lambda book: enrich_books_with_characters(book)
)

book_metadata_pipeline = fetch_metadata_runnable | enrich_with_characters_runnable
full_book_pipeline = book_metadata_pipeline | RunnableLambda(process_book_characters)

# %% [markdown]
# #### Execução da pipeline

# %%
if __name__ == "__main__":

    path = 'livros_ptbr.csv'
    if os.path.exists(path):
        df = pd.read_csv(path)
        book_ids = df['id'][51:]
    else:
        print("Arquivo não encontrado, usando um ID de teste.")
        book_ids = [69187]

    for book_id in book_ids:
        try:
            pipeline_input = {"book_id": book_id}
            results = full_book_pipeline.invoke(pipeline_input)

            for index, item in enumerate(results):
                print(f"\n\nResultado {index + 1}:")
                print(item)

                sleep(5)
        except Exception as error:
            print("Falha ao executar extração de dados para o livro", str(error))
# Out:
# Processando Graziella para o livro A capital federal (impressões de um sertanejo)
#
#
# Processando Contos Phantasticos para o livro Contos Phantasticos: segunda edição correcta e ampliada
#
#
# Resultado 1:
# {'character_name': 'Contos Phantasticos', 'character_context': CharacterLLMInput(book=BookMetadataOutput(title='Contos Phantasticos: segunda edição correcta e ampliada', authors=[Person(name='Braga, Teófilo', birth_year=1843, death_year=1924)], summaries=['"Contos Phantasticos" by Teófilo Braga is a collection of short stories written in the late 19th century. This work explores themes of passion, melancholy, and existential contemplation, presenting characters deeply immersed in their own emotional struggles and the broader human experience. The stories blend poetic language with a philosophical undertone, drawing readers into the internal conflicts of its characters.  The opening of "Contos Phantasticos" introduces a reflective preface where Braga revisits his earlier works with both nostalgia and critique. He recounts the personal struggles faced during the creation of these stories, mingling memories with literary analysis. The narrative then shifts to portray a character, presumably a young woman, enveloped in a profound sadness despite her beauty and youth, hinting at deeper existential themes. The tone is introspective, evoking a sense of longing and the complexities of love, ultimately setting the stage for the intricate and emotionally charged tales to follow. (This is an automatically generated summary.)'], subjects=['Fiction', 'Short stories, Portuguese'], characters=['Contos Phantasticos'], languages=[], copyright=None, media_type=None, text_url=HttpUrl('https://www.gutenberg.org/ebooks/32646.txt.utf-8')), character_name='Contos Phantasticos', snippets={1: 'This ebook is for the use of anyone anywhere in the United States and\nmost other parts of the world at no cost and with almost no restrictions\nwhatsoever. You may copy it, give it away or re-use it under the terms\nof the Project Gutenberg License included with this ebook or online\nat www.gutenberg.org. If you are not located in the United States,\nyou will have to check the laws of the country where you are located\nbefore using this eBook.', 6: 'Credits: Produced by Pedro Saborano and the Online Distributed\n        Proofreading Team at https://www.pgdp.net (This book was\n        produced from scanned images of public domain material\n        from the Google Print project.)', 8: 'Produced by Pedro Saborano and the Online Distributed\nProofreading Team at https://www.pgdp.net (This book was\nproduced from scanned images of public domain material\nfrom the Google Print project.)', 654: 'Updated editions will replace the previous one—the old editions will\nbe renamed.'}), 'llm_output': '```json\n{\n  "inferences": [\n    {\n      "id": "1",\n      "traits": [\n        "generoso",\n        "altruísta",\n        "responsável",\n        "ético"\n      ]\n    },\n    {\n      "id": "654",\n      "traits": [\n        "perfeccionista",\n        "metódico",\n        "responsável",\n        "inovador"\n      ]\n    }\n  ],\n  "resume": "Contos Phantasticos é um trabalho generoso e altruísta, disponível gratuitamente e com poucas restrições. É responsável e ético em sua distribuição, além de ser metódico e perfeccionista em suas atualizações."\n}\n```'}
#
#
# Processando Maria do Carmo para o livro Flirts
#
#
# Resultado 1:
# {'character_name': 'Maria do Carmo', 'character_context': CharacterLLMInput(book=BookMetadataOutput(title='Flirts', authors=[Person(name='Vasconcellos, Henrique de', birth_year=1876, death_year=1924)], summaries=['"Flirts" by Henrique de Vasconcellos is a collection of short stories written in the early 20th century. The work explores themes of love, flirtation, and social interactions, reflecting on the lives of various characters navigating romance and relationships. The stories likely feature a range of humorous and poignant exchanges between lovers and acquaintances, capturing the intricacies of human emotions.  At the start of the collection, we are introduced to a setting that resembles a flirtation school, where a professor instructs a naive student named Maria do Carmo, who seeks to learn the art of flirting to navigate her new life in Lisbon. The professor is depicted as knowledgeable yet somewhat cynical, guiding his disciple through the nuances of societal expectations and flirtation techniques. Their dialogue reveals a blend of sophistication and humor as they discuss appearance, conversation, and the nature of romantic encounters, setting the tone for the exploration of interpersonal dynamics throughout the stories. (This is an automatically generated summary.)'], subjects=['Fiction'], characters=['Maria do Carmo'], languages=[], copyright=None, media_type=None, text_url=HttpUrl('https://www.gutenberg.org/ebooks/35073.txt.utf-8')), character_name='Maria do Carmo', snippets={65: 'O PROFESSOR--Não fica mal um pouco de poesia... Falar do mar e do\nestremecimento da lua sobre as aguas inquietas, comparar-se á agua\nmovediça e infiel... Emfim são coisas para mais tarde. Vamos aos\npreliminares. Ah! Antes de mais nada: o nome de v. ex.ª?', 118: 'Maria do Carmo, curvada sobre a meza, folheia os ultimos _envois_ de\n    Paquin e Redfern. Um candieiro com um largo quebra-luz de seda e\n    rendas lança-lhe sobre o cabello uma aureola de oiro. O corpo está\n    mergulhado na penumbra. Na sala, os moveis tomam aspectos\n    fantasticos. Os espelhos teem um brilho pallido. Gonçalo, ao entrar,\n    beija a mão que Maria do Carmo lhe estende, sem levantar os olhos\n    dos papeis.', 119: 'MARIA DO CARMO--trinta annos, com dez de casamento. Sem filhos. A\n    vida passa-se-lhe em visitas, _raouts_, recéções e bailes. Alguns\n    livros da moda, recommendados por Marcel Ballot, no _Figaro_, e Jean\n    Lorrain, por curiosidade. Interessante como um enigma, ás vezes\n    perversa. Não se lhe conhece um amante, mas indicam-se muitos. Não\n    toca piano.', 120: 'GONÇALO--não tem uma branca, mas no meio da animação, ficticia,\n    vê-se um grande cançaço de viver, como se tivesse experimentado\n    tudo. Procura por toda a parte, como um _gourmet_, o manjar fino.\n    Epicurista, delicadamente depravado, como um _roué_ da Restauração,\n    ou um elegante do fim da republica romana.'}), 'llm_output': '```json\n{\n  "inferences": [\n    {\n      "id": "118",\n      "traits": [\n        "vaidoso",\n        "frio"\n      ]\n    },\n    {\n      "id": "119",\n      "traits": [\n        "vaidoso",\n        "curioso",\n        "misterioso",\n        "manipulador",\n        "astuto"\n      ]\n    }\n  ],\n  "resume": "Maria do Carmo é uma mulher de trinta anos, casada, sem filhos, que leva uma vida social intensa e superficial. É vaidoso, curioso, misterioso, manipulador e astuto, mantendo uma aura enigmática e um certo distanciamento."\n}\n```'}
#
#
# Processando Alfonso XII para o livro O Romance da Rainha Mercedes
# Falha ao executar extração de dados para o livro 1 validation error for CharacterLLMInput
# snippets
#   Input should be a valid dictionary [type=dict_type, input_value=[], input_type=list]
#     For further information visit https://errors.pydantic.dev/2.11/v/dict_type
#
#
# Processando Gervasio Vila-Nova para o livro A confissão de Lucio,: Narrativa.
#
#
# Resultado 1:
foi sempre havido pelos outros, que\no tractavam com uma deferencia excepcional.', 38: "Ainda depois da morte do irmão, D. Luiz, costumado ao viver da grande\nsociedade e á esplendida elegancia das côrtes estrangeiras, não\nabandonou a carreira que encetára. Secretario de embaixada em Vienna,\ncasou alli com a filha de um fidalgo portuguez, que então residia n'essa\ncorte, encarregado de negocios politicos.", 39: "Ao manifestarem-se em Portugal os pri ...
#
#
# Processando Emilio para o livro O Arrependimento
#
#
# Resultado 1:
# {'character_name': 'Emilio', 'character_context': CharacterLLMInput(book=BookMetadataOutput(title='O Arrependimento', authors=[Person(name='Castelo Branco, Camilo', birth_year=1825, death_year=1890)], summaries=['"O Arrependimento" by Camilo Castelo Branco is a novel written in the mid-19th century. This work explores themes of morality, redemption, and the complexity of human nature, focusing on the emotional and psychological struggles of its characters as they navigate the consequences of their choices.  The narrative revolves around Emilio da Cunha and his younger nephew, Roberto. After Emilio takes in Roberto following the demise of his brother, he hopes to guide him toward a better path. However, Roberto\'s negative influences lead him astray, resulting in a life filled with crime and despair. The story takes a turn when Roberto, after a moment of realization of his misdeeds, embarks on a journey to redeem himself, striving to earn back the trust and forgiveness of his uncle and cousin, Valentina. The novel ultimately emphasizes the potential for regeneration and the significance of compassion and understanding in overcoming past mistakes. (This is an automatically generated summary.)'], subjects=['Portuguese fiction -- 19th century', 'Short stories, Portuguese'], characters=['Emilio', 'Roberto'], languages=[], copyright=None, media_type=None, text_url=HttpUrl('https://www.gutenberg.org/ebooks/23346.txt.utf-8')), character_name='Emilio', snippets={26: '--Emilio da Cunha era o mais velho de tres irmãos, dos quaes, o mais\nnovo, vivia ha muitos annos no Rio de Janeiro, onde tinha alcançado\nfortuna. O segundo nunca deixou o Porto, sendo sempre infeliz nos seus\ncommettimentos e especulações. Emilio da Cunha, á custa de muito\ntrabalho e economias, pôde alcançar uma fortunasinha, que lhe permittia\nesperar com socego, o momento de descançar da vida laboriosa em que\ntinha vivido.', 27: "Uma quarta pessoa completava esta familia, que era uma irmã, que tendo\nseguido seu marido á India, para onde elle tinha sido despachado, e não\nvindo nenhum d'elles a figurar n'esta minha historia, não lh'os\nrecordarei mais.", 28: "Aconteceu que o irmão de Emilio da Cunha, que residia no Porto, por uma\nd'estas catastrophes que occasionam os jogos de bolsa, falliu. Teve tal\nsentimento por este facto, que falleceu tres dias depois, atacado d'uma\nfebre cerebral. A herança, que deixou, foram dividas e um filho.", 29: 'Emilio da Cunha, que tinha um coração bondoso, e um caracter\npundonoroso, para que a memoria de seu irmão não ficasse deshonrada,\ncomprometteu-se a pagar as dividas e recolheu em sua casa o filho para\nlhe substituir o pai, que tinha perdido; procedimento louvavel, e digno\nde se admirar, sabendo-se que elle tinha uma filha, para quem, passados\nquatro ou cinco annos tinha a procurar um casamento vantajoso.', 30: "Roberto, se chamava o sobrinho de Emilio da Cunha, tinha já 15 annos\nd'idade, mas o pai, inteiramente entregue ás especulações, e aos\ncuidados, que ellas trazem comsigo, descuidou completamente a sua\neducação, por isso o seu retrato moral, n'esta occasião, nada tinha de\nvantajoso; o espirito tinha
nda America_, que se perdeu inteiramente, e de uma memoria em pró da\nacclamação d'el-rei D. João IVº, publicada em Leyde (Hollanda), no anno\nde 1641, com o titulo de _Prognostico y respuesta á una pergunta de\nun caballero muy ilustre sobre las cosas de Portugal_; condemnado pelo\ntribunal do Santo Officio, relaxado em estatua no auto de fé de 6 de\nAbril de 1643, por apostata da religião catholica, e casado com mulher\nschismatica; e fallecido emfim em Lisboa, naturalmente, segundo o dizer\nde varias tradições; pela violencia, conforme outras não menos procedentes.", 38: "Fallando d'elle igualmente Innocencio Francisco da Silva no seu\n_Diccionario biographico e bibliographico portuguez e brazileiro_,\naccrescenta que pertencêra á companhia de Jesus em São Paulo, e fôra\ngarroteado no auto de fé de 15 de Dezembro de 1647.", 39: 'Outros escriptores, que procurárão lembrar-lhe tambem o nome, e nós\nparticularmente no supplemento annexo á obra dos _Varões illustres do\nBrazil durante os tempos coloniaes_, repetírão sómente o que\navançára o abbade Diogo Barbosa, porque nem-uns esclarecimentos lográrão\nmais a este respeito, por maiores pesquizas que houvessem commettido.', 40: 'Parece pois evidente que se não poderá jámais esboçar um estudo\nbiographico e regular ácerca de Manuel de Moraes, por lhe faltarem  ...
#
#
# Processando Cabinda para o livro A Filha do Cabinda
#
#
# Resultado 1:
# {'character_name': 'Cabinda', 'character_context': CharacterLLMInput(book=BookMetadataOutput(title='A Filha do Cabinda', authors=[Person(name='Campos, Alfredo', birth_year=1847, death_year=1906)], summaries=['"A Filha do Cabinda" by Alfredo Campos is a romance written in the late 19th century. The story unfolds around the complex relationships between a beautiful young woman named Magdalena, the titular daughter of Cabinda, a devoted former slave, and her father, Jorge de Macedo. The narrative captures themes of love, loss, and the deep emotional bonds that transcend social boundaries, as it delves into the lives of these characters in Brazil.    At the start of the story, the narrative introduces Cabinda, a black former slave who, despite the traumas of slavery and loss of his family, has formed a loving bond with Magdalena since her childhood. As Magdalena grows up in privilege, she is surrounded by love from both her father and Cabinda, which is contrasted with her feelings of vague sadness and longing. The opening sets the stage for the inevitable challenges of love and acceptance, particularly as Magdalena begins to recognize her burgeoning feelings for a white man named Luiz, leading to an exploration of societal norms and personal desires. (This is an automatically generated summary.)'], subjects=['Slavery -- Brazil -- Fiction'], characters=['Cabinda', 'Jorge de Macedo', 'Luiz', 'Magdalena'], languages=[], copyright=None, media_type=None, text_url=HttpUrl('https://www.gutenberg.org/ebooks/21961.txt.utf-8')), character_name='Cabinda', snippets={1: 'This ebook is for the use of anyone anywhere in the United States and\nmost other parts of the world at no cost and with almost no restrictions\nwhatsoever. You may copy it, give it away or re-use it under the terms\nof the Project Gutenberg License included with this ebook or online\nat www.gutenberg.org. If you are not located in the United States,\nyou will have to check the laws of the country where you are located\nbefore using this eBook.', 7: 'Credits: Produced by Pedro Saborano. (produced from scanned images\n        of public domain material from Google Book Search)', 9: 'Produced by Pedro Saborano. (produced from scanned images\nof public domain material from Google Book Search)', 25: 'A «filha do cabinda» é uma recordação singellissima de muitas, que\nconservo, de alguns annos passados, na formosa capital do vasto Imperio\ndo Brazil.', 26: "Transcrevi-a do livro da minha memoria, para este que aqui vai,\nsingello, despretencioso, sem flores e sem perfumes, unicamente no\nintuito de matar horas d'enfado e dias de melancholia.", 36: "A filha do cabinda é formosa como a visão d'um sonho celeste; meiga como\no canto do sabiá, poisado nos galhos do cajueiro, e ingenua como a\nvirgem da innocencia.", 37: 'O cabinda é negro, e negro de raça fina, mas é branca a sua filha, e\nfilha, porque o velho escravo quer muito á senhora moça, que elle\nbeijava e embalava no seu collo, quando era pequenina.', 38: "Revê-se n'ella, e n'ella se mira doido d'affeição o pobre negro, e tanto\na gravou na ideia, tanto a traz no coração, que chega até a esquecer-se\ndo trabalho, sujeitando-se ás reprehensões do seu senhor, para,\ninsensivelmente, se entregar a scismar n'ella, que é tão bondosa, tão\nmeiga e tão carinhosa para elle; n'ella, que, por uma destas illusões,\nd'estas miragens, d'estas doidices, d'um grande affecto e d'uma viva\nsympathia, chega a julgar realmente sua filha.", 41: "Um dia, não sabe como, achou-se com todos elles dentro d'um navio, que\ncomeçou a affastal-o, cada vez mais, da sua patria. Passou assim algum\ntempo, entre as duas immensidões, o mar e o céo, sem sentir saudades da\nsua terra, porque levava ainda ao seu lado aquelles que lhe davam\nalegria. Depois, pozeram-o de novo em terra, levaram-o a elle e aos seus\ncompanheiros para uma grande casa, onde os brancos começaram a disputar\no preço por que haviam de compral-os."}), 'llm_output': '```json\n{\n  "inferenc ...
#
#
# Processando Claudio para o livro Transviado
#
#
# Resultado 1:
# {'character_name': 'Claudio', 'character_context': CharacterLLMInput(book=BookMetadataOutput(title='Transviado', authors=[Person(name='Lima, Jaime de Magalhães', birth_year=1859, death_year=1936)], summaries=['"Transviado" by Jaime de Magalhães Lima is a romance illustrated with magnificent engravings written in the late 19th century. The narrative follows Claudio de Souza Portugal, a young man pondering through his experiences and encounters as he navigates between the charm of provincial life and the allure of broader horizons, particularly those of the vibrant Lisbon and beyond.  The opening portion of the work introduces us to Claudio as he arrives at a small train station near Coimbra, where he unexpectedly encounters a couple, Ricardo and Emilia. Their interaction reveals Claudio\'s yearning for emotional connection and reflects on the stark contrast between the mundane life of the provincial town and his rich memories of travels and adventures in foreign lands. As the trio boards the carriage to return to Albergaria, the budding dynamics begin to unfold between Claudio and Emilia, who expresses a longing for city life, setting the stage for themes of desire, longing, and the complications of amorous relationships amidst the vibrant backdrops of both countryside and urban venues. (This is an automatically generated summary.)'], subjects=['Portuguese fiction -- 19th century'], characters=['Claudio', 'Claudio de Souza Portugal', 'Emilia'], languages=[], copyright=None, media_type=None, text_url=HttpUrl('https://www.gutenberg.org/ebooks/25945.txt.utf-8')), character_name='Claudio', snippets={36: 'E o rapaz ia a sentar-se quando o outro, abruptamente, o obriga a\naprumar-se apontando-lhe a mulher.', 37: '--Minha mulher... o sr Claudio de Souza Portugal, um cavalheiro muito\nillustrado e do meu maior respeito!', 39: "--Que extravagante modo de vêr! começou Claudio. Nas cidades, onde não\nfaltam recursos, a _Companhia_ dá-nos uma sala de espera com certo\nconforto, e aqui, n'este deserto, no meio d'um charco, reduz todas as\ncommodidades dos pobres passageiros a um banco mal pintado e frequentado\nsabe Deus por quem. Na Suissa chega a haver, nas estações que estão nas\ncircumstancias d'esta, uns pequenos quartos em que se pernoita com\nagasalho e aceio. Aqui, que barbarie!... Havemos de ser sempre assim; um\npaiz de toiros ha-de ser forçosamente um paiz de campinos. Tambem tem a\nsua belleza, é verdade; mas, quando se tem frio, uma manta do Ribatejo e\nduas taboas de pinho, confessemos, são pouco.", 40: 'E fitava a mulher, nervoso, contente com esta apparição inesperada,\ncaptivo da sua graça.', 43: 'Ella, sorrindo, replicou:--Bem diz o ditado que dá Deus nozes a quem não\ntem dentes. Só eu aborreço cordealmente a vida de provincia e estou\ncondemnada a soffrel-a. Já não queria Paris nem Vienna, com Lisboa me\ncontentava. Nem isso!... Não posso comprehender o mundo sem muita gente.\nA Avenida e S. Carlos e o Campo Grande e as praças e as ruas, tudo isso\né para mim encantador, e infinitamente melhor que o pó e os tamancos da\nvilla de Albergaria. Eu sei que é de máu gosto não elogiar as bellezas\ndo campo, mas fui educada em Lisboa e hei-de ser lisboeta até ao fim da\nvida. Não... Parece-me sentir se o comboio. Até já, que nós tambem não\nsaimos, concluiu ella, erguendo-se, com visivel interesse em continuar a\npalestra.', 44: 'O comboio entrava na gare e separaram-se, dirigindo se cada um ás\ncarruagens em que descobriam as pessoas que procuravam. Depois,\nrapidamente, bateu o signal da partida, a confusão de pregoeiros de\njornaes e de passageiros que corriam do restaurante dissipou-se, e,\nnovamente, na gare ficaram sós Claudio, os seus interlocutores, e poucos\nempregados que arrastadamente recolhiam da sua tarefa a dormitar pelos\narmazens, entre as bagagens.', 45: 'Claudio approximou-se do par que momentos antes tinha deixado e\noffereceu-lhe logar na sua carruagem para regressarem juntos a\nAlbergaria.', 50: '--Oh! pelo ...
#
#
# Processando Dona Loura para o livro Mundanismos
#
#
# Resultado 1:
# {'character_name': 'Dona Loura', 'character_context': CharacterLLMInput(book=BookMetadataOutput(title='Mundanismos', authors=[Person(name='Diniz, Almachio', birth_year=1880, death_year=1937)], summaries=['"Mundanismos" by Almachio Diniz is a collection of short stories written in the early 20th century. The work encompasses various narratives that engage with themes of human relationships, societal norms, and personal struggles, likely reflecting the socio-cultural context of its time. The prominent characters include Nedda, a discontented wife navigating her tumultuous marriage, and other figures who find themselves entangled in desires and moral dilemmas.  The opening of "Mundanismos" introduces us to Nedda, who is frustrated with her husband Saul\'s lack of communication and emotional connection. As she converses with her mother Dona Loura, their dialogue reveals the complexities of Nedda\'s disillusionment with her marriage, highlighting her longing for understanding and a fulfilling relationship. The story hints at underlying tensions and expectations regarding love and duty, setting the stage for explorations of intimacy, fidelity, and self-identity as Nedda confronts her marital dissatisfaction. (This is an automatically generated summary.)'], subjects=['Fiction'], characters=['Dona Loura', 'Saul'], languages=[], copyright=None, media_type=None, text_url=HttpUrl('https://www.gutenberg.org/ebooks/30413.txt.utf-8')), character_name='Dona Loura', snippets={40: 'E NEDDA, abysmada com a indifferença delle que apenas lhe não\n    dirigia um monosyllabo desde a hora do facto, comprehendeu logo que\n    DONA LOURA, a sua mãe, era uma interprete das indisposições do genro...', 41: 'Num canapé, as duas mulheres, DONA LOURA, archaica nas suas vestias\n    de capote e turbante, e NEDDA, deliciosamente matutina num roupão\n    branco que descansava, _sans-dessous_, sobre a finissima camizêta\n    de cambraias,--sentaram-se, afundando em concavos a palha flaccida\n    do cansado movel...'}), 'llm_output': '```json\n{\n  "inferences": [\n    {\n      "id": "40",\n      "traits": [\n        "observador",\n        "mediador"\n      ]\n    },\n    {\n      "id": "41",\n      "traits": [\n        "conservador"\n      ]\n    }\n  ],\n  "resume": "Dona Loura é uma mulher observadora e mediadora, capaz de interpretar as disposições alheias. Ela se apresenta com um estilo de vestuário conservador e arcaico."\n}\n```'}
#
#
# Processando Braga para o livro Idyllios á beira d'agua: Romance original
#
#
# Resultado 1:
# {'character_name': 'Braga', 'character_context': CharacterLLMInput(book=BookMetadataOutput(title="Idyllios á beira d'agua: Romance original", authors=[Person(name='Pimentel, Alberto', birth_year=1849, death_year=1925)], summaries=['"Idyllios á beira d\'agua" by Alberto Pimentel is a novel written in the late 19th century. The story explores themes of nature, tranquility, and the complexities of young love through the experiences of its main character, Eduardo Valladares, a sixteen-year-old poet navigating his emotions and interpersonal relationships in a picturesque setting. The narrative intertwines the serene landscapes around the Bom Jesus do Monte with the inner struggles and growth of its characters, hinting at a reflective and sentimental exploration of life.  The opening of the novel reveals Eduardo Valladares as he settles into his new life in Braga after moving away from his home. He experiences nostalgia for his past, mingled with a burgeoning sense of hope and discovery as he interacts with the world around him. The introduction sets a reflective tone, as Eduardo contemplates the impact of nature on his spirit while being influenced by his budding feelings for Maria Luiza Machado, a girl he met during social visits. The initial chapters also provide insight into the lives of Eduardo\'s family and friends, hinting at social dynamics and parental concerns regarding his aspirations for poetry and connection to love, setting the stage for the unfolding narrative of youthful ambition and emotional awakening. (This is an automatically generated summary.)'], subjects=['Portuguese fiction -- 20th century'], characters=['Braga', 'Eduardo Valladares'], languages=[], copyright=None, media_type=None, text_url=HttpUrl('https://www.gutenberg.org/ebooks/62853.txt.utf-8')), character_name='Braga', snippets={24: 'Fui subindo, subindo e remoçando a cada passo que dava, a cada momento\nque fugia.', 25: 'Demorei-me tres dias na estancia suavissima do Bom Jesus do Monte, que\ntanto era preciso para lograr um remoçamento completo, e, na tarde do\nsegundo dia, afigurou-se-me vêr, a distancia, na alameda da Mãe d’Agua,\num homem que me inspirara a maxima sympathia quando pela primeira vez\nlhe falei em Braga—o padre Eduardo Valladares.', 26: 'O leitor, que não exige que o romancista venha expôr a face do martyr á\nluz do sol, para que todos o conheçam e o apontem, permitte-me decerto\neste pseudonymo com que me corre obrigação de velar a verdadeira\npersonagem do mundo real.', 53: 'Manda, porém, a verdade dizer que a nomeada do talentoso advogado não\nencontrou entre os demandistas portuenses o écho que remurmurava ainda\nnos salgueiraes do Mondego. A levada dos clientes, sempre tumultuosa, não\naffluira á banca do moço bacharel.', 54: 'João Nicolau de Brito, proprietario em Braga, conheceu que á mediania\nsuada do genro pesava a educação do unico filho que tinha, e chamou á sua\ncompanhia o neto, de dezeseis annos d’edade.', 55: '
ivera motivo para se revelar. Deslumbrada por esse\nesplendido conjuncto de predicados, Lucinda tentára fixar a attenção do\ngentil moço, e a _coquette_ conseguira-o em breve, mas, quando se\ntratára de dar o passo decisivo, manifestára-se toda a timidez do\nespirito virginal de Frederico. Era o seu primeiro amor, e só os tolos\nconseguem atravessar affoitamente essas columnas d'Hercules. Lucinda,\nexperimentada n'essas questões, comprehendera primeiramente o embaraço\ndo mancebo, e, lisongeando-se com isso, entendera tambem que o devia\nauxiliar. Mas o que animaria qualquer outro, acanhou ainda mais, se me\npermittem o termo, a timidez desconfiada de Frederico. Se Lucinda fosse\numa timida menina, que córasse como elle corava, que tremesse como\nelle tremia, os olhos d'ambos fallariam tanto, as palpebras mesmo,\nabaixando-se a um tempo, teriam uma linguagem tão eloquente, que afinal\nos labios ver-se-hiam obrigados a traduzir em palavras esse mudo idioma.\nPorém, como podia succeder semelhante cousa, se o olhar ardente de\nLucinda deslumbrava aquelle em quem se fitava, se a sua tranquilla\nsuperioridade assustava Frederico, e o fazia tremer a cada instante, com\no receio de desempenhar o papel de criança ridicula diante d'essa\nesplendida mulher?!", 52: 'O ridiculo, que espera nos dois extremos da estrada da vida tanto os que\navançam como fanfarrões, como os que recuam com demasiada fraquesa,\nassustando Frederico que temia vel-o diante de si, assaltava-o quando\nelle para lhe fugir retrogradava sem ter animo para obedecer ao férvido\nolhar, que lhe dizia: «Ávante.» O pobre rapaz, vendo assim de subito\ndesfeitos em pó os seus planos estra ...
#
#
# Processando Elisa para o livro Suicida
#
#
# Resultado 1:
# {'character_name': 'Elisa', 'character_context': CharacterLLMInput(book=BookMetadataOutput(title='Suicida', authors=[Person(name='Castelo Branco, Camilo', birth_year=1825, death_year=1890)], summaries=['"Suicida" by Camilo Castelo Branco is a poignant novel written in the late 19th century. The book delves into the theme of suicide, exploring the complex emotions surrounding loss, despair, and the human condition through the lens of a tragic figure. It reflects the societal pressures and personal struggles faced by the protagonist, who ultimately succumbs to the darkness of their circumstances.  The narrative centers around Elisa Loeve-Weimar, a woman of remarkable beauty and talent who experiences devastating losses throughout her life, including the deaths of her beloved children and the collapse of her marriage to José Joaquim Gonçalves Basto. As she grapples with her fading dreams and mental deterioration, Elisa\'s journey reveals the depths of her despair and the societal neglect of those in emotional pain. Ultimately, faced with the agonizing reality of her life and believing she is condemned to misery, she takes her own life, leaving behind a reflection on the tragic consequences of despair and unfulfilled potential, all while intertwining with the author\'s broader commentary on love, loss, and societal indifference. (This is an automatically generated summary.)'], subjects=['Loève-Veimars, Elisa, 1805-1875'], characters=['Elisa', 'Elisa Loeve-Weimar', 'José Joaquim'], languages=[], copyright=None, media_type=None, text_url=HttpUrl('https://www.gutenberg.org/ebooks/24339.txt.utf-8')), character_name='Elisa', snippets={16: 'Livraria Internacional\n  de\n  Ernesto Chardron, Editor\n  PORTO E BRAGA\n  1880', 18: 'A senhora, que teve este nome, suicidou-se com um tiro, no Porto, no dia\n30 do mez passado[1].', 26: "Nos arrabaldes de Londres, em uma quinta de delicias, quantas póde imitar\nda natureza a arte britannica, vivia, n
amelia, porque até ao momento\nem que o estudante chegou, suppunha eu que toda a familia do parocho se\nlimitaria a alguma ama, e alguns pequenitos, que, de ordinario, são\nafilhados do padre. Depois das perguntas do meu illustre companheiro de\nhospedagem, fiquei sabendo que n'aquella casa existia uma snr.^a D.\nAmelia, e um senhor delegado de * * *.", 83: 'Padre Joaquim contou ao academico as minhas aventuras de caçador;\ndisse-lhe que me tinha achado muito fino (referia-se naturalmente á\nmagresa), e fez a apologia dos meus olhos, que, naturalmente, revelavam\numa extraordinaria esperteza, espiritualisados pelo espirito de vinho,\nque o sacerdote me injectou nas veias marasmadas pelo frio.', 87: '--Snr. Valladares--disse o padre ao estudante--minha cunhada ergueu-se\nda cama para vir comprimental-o...', 88: '--É uma grande consideração, que eu lhe não mereço; mas a delicadeza da\nsnr.^a D. Amelia é sempre um severo preceito que ella se impõe.', 93: "--Eu bem lhe disse que não fosse... v. s.^a teimou, agora já sabe que os\nconselhos d'uma mulher não são sempre pieguices...", 95: "--D'este modo que vê... Tossindo sempre, sempre mal, sem descanço d'este\nlado, que me parece que já não vive, se não para matar o resto de vida\nque tenho...", 108: "Esta rapida apparição impressionou-me muito. Queria fazer mil perguntas;\nmas eu não tinha a quem. O padre e o estudante fallaram em assumptos,\nque me não interessavam nada. O que eu queria era a vida, a historia, os\nsoffrimentos, a poesia d'aquella mulher. Eu tinha lido, dias antes, não\nsei que romance, onde vira uma mulher assim...", 109: 'Appareceu um taboleiro com a cêa. O abbade fez o prato de D. Amelia. Era\numa aza de gallinha, que elle mesmo lhe serviu.', 110: "Valladares tambem comeu do pucaro da doente. Eu, com o abbade, entramos\ncorajosamente n'um coelho guisado, cuja retaguarda cortamos com um\nexcellente caldo verde, e lourejantes castanhas assadas com manteiga.", 115: "Eu fui um grande fallador, n'aquella idade, em que pensava menos. O meu\nrecente amigo sympathisou com a minha garrula eloquencia, e dava signaes\nde desenfado, quando naturalmente devêra querer dormir, depois de uma\nfatigante jornada, em dia de neve.", 116: 'Eu não era rapaz que, por delicadeza, calasse a minha curiosidade a\nrespeito de D. Amelia.'}), 'llm_output': '```json\n{\n  "inferences": [\n    {\n      "id": "87",\n      "trai ...

# %%
pd.read_csv("characters_dataset.csv").head(20)
# Out:
#                                                 title  \
# 0      A capital federal (impressões de um sertanejo)
# 1   Contos Phantasticos: segunda edição correcta e...
# 2   Contos Phantasticos: segunda edição correcta e...
# 3                                              Flirts
# 4                                              Flirts
# 5      A capital federal (impressões de um sertanejo)
# 6   Contos Phantasticos: segunda edição correcta e...
# 7   Contos Phantasticos: segunda edição correcta e...
# 8                                              Flirts
# 9                                              Flirts
# 10                  A confissão de Lucio,: Narrativa.
# 11                  A confissão de Lucio,: Narrativa.
# 12                  A confissão de Lucio,: Narrativa.
# 13                  A confissão de Lucio,: Narrativa.
# 14                  A confissão de Lucio,: Narrativa.
# 15                  A confissão de Lucio,: Narrativa.
# 16                  A confissão de Lucio,: Narrativa.
# 17                  A confissão de Lucio,: Narrativa.
# 18                  A confissão de Lucio,: Narrativa.
# 19                  A confissão de Lucio,: Narrativa.
#
#                                               authors  \
# 0   [{"name": "Coelho Netto, Henrique", "birth_yea...
# 1   [{"name": "Braga, Teófilo", "birth_year": 1843...
# 2   [{"name": "Braga, Teófilo", "birth_year": 1843...
# 3   [{"name": "Vasconcellos, Henrique de", "birth_...
# 4   [{"name": "Vasconcellos, Henrique de", "birth_...
# 5   [{"name": "Coelho Netto, Henrique", "birth_yea...
# 6   [{"name": "Braga, Teófilo", "birth_year": 1843...
# 7   [{"name": "Braga, Teófilo", "birth_year": 1843...
# 8   [{"name": "Vasconcellos, Henrique de", "birth_...
# 9   [{"name": "Vasconcellos, Henrique de", "birth_...
# 10  [{"name": "Sá-Carneiro, Mário de", "birth_year...
# 11  [{"name": "Sá-Carneiro, Mário de", "birth_year...
# 12  [{"name": "Sá-Carneiro, Mário de", "birth_year...
# 13  [{"name": "Sá-Carneiro, Mário de", "birth_year...
# 14  [{"name": "Sá-Carneiro, Mário de", "birth_year...
# 15  [{"name": "Sá-Carneiro, Mário de", "birth_year...
# 16  [{"name": "Sá-Carneiro, Mário de", "birth_year...
# 17  [{"name": "Sá-Carneiro, Mário de", "birth_year...
# 18  [{"name": "Sá-Carneiro, Mário de", "birth_year...
# 19  [{"name": "Sá-Carneiro, Mário de", "birth_year...
#
#                                             summaries  \
# 0   ["\"A Capital Federal (Impressões de um Sertan...
# 1   ["\"Contos Phantasticos\" by Teófilo Braga is ...
# 2   ["\"Contos Phantasticos\" by Teófilo Braga is ...
# 3   ["\"Flirts\" by Henrique de Vasconcellos is a ...
# 4   ["\"Flirts\" by Henrique de Vasconcellos is a ...
# 5   ["\"A Capital Federal (Impressões de um Sertan...
# 6   ["\"Contos Phantasticos\" by Teófilo Braga is ...
# 7   ["\"Contos Phantasticos\" by Teófilo Braga is ...
# 8   ["\"Flirts\" by Henrique de Vasconcellos is a ...
# 9   ["\"Flirts\" by Henrique de Vasconcellos is a ...
# 10  ["\"A Confissão de Lucio: Narrativa\" by Mário...
# 11  ["\"A Confissão de Lucio: Narrativa\" by Mário...
# 12  ["\"A Confissão de Lucio: Narrativa\" by Mário...
# 13  ["\"A Confissão de Lucio: Narrativa\" by Mário...
# 14  ["\"A Confissão de Lucio: Narrativa\" by Mário...
# 15  ["\"A Confissão de Lucio: Narrativa\" by Mário...
# 16  ["\"A Confissão de Lucio: Narrativa\" by Mário...
# 17  ["\"A Confissão de Lucio: Narrativa\" by Mário...
# 18  ["\"A Confissão de Lucio: Narrativa\" by Mário...
# 19  ["\"A Confissão de Lucio: Narrativa\" by Mário...
#
#                                              subjects  \
# 0   ["Brazilian literature", "Romance fiction, Bra...
# 1            ["Fiction", "Short stories, Portuguese"]
# 2            ["Fiction", "Short stories, Portuguese"]
# 3                                         ["Fiction"]
# 4                                         ["Fiction"]
# 5   ["Brazilian literature", "Romance fiction, Bra...
# 6            ["Fiction", "Short stories, Portuguese"]
# 7            ["Fiction", "Short stories, Portuguese"]
# 8                                         ["Fiction"]
# 9                                         ["Fiction"]
# 10             ["Portuguese fiction -- 20th century"]
# 11             ["Portuguese fiction -- 20th century"]
# 12             ["Portuguese fiction -- 20th century"]
# 13             ["Portuguese fiction -- 20th century"]
# 14             ["Portuguese fiction -- 20th century"]
# 15             ["Portuguese fiction -- 20th century"]
# 16             ["Portuguese fiction -- 20th century"]
# 17             ["Portuguese fiction -- 20th century"]
# 18             ["Portuguese fiction -- 20th century"]
# 19             ["Portuguese fiction -- 20th century"]
#
#                          characters  \
# 0        ["Graziella", "Sertanejo"]
# 1           ["Contos Phantasticos"]
# 2           ["Contos Phantasticos"]
# 3                ["Maria do Carmo"]
# 4                ["Maria do Carmo"]
# 5        ["Graziella", "Sertanejo"]
# 6           ["Contos Phantasticos"]
# 7           ["Contos Phantasticos"]
# 8                ["Maria do Carmo"]
# 9                ["Maria do Carmo"]
# 10  ["Gervasio Vila-Nova", "Lucio"]
# 11  ["Gervasio Vila-Nova", "Lucio"]
# 12  ["Gervasio Vila-Nova", "Lucio"]
# 13  ["Gervasio Vila-Nova", "Lucio"]
# 14  ["Gervasio Vila-Nova", "Lucio"]
# 15  ["Gervasio Vila-Nova", "Lucio"]
# 16  ["Gervasio Vila-Nova", "Lucio"]
# 17  ["Gervasio Vila-Nova", "Lucio"]
# 18  ["Gervasio Vila-Nova", "Lucio"]
# 19  ["Gervasio Vila-Nova", "Lucio"]
#
#                                             text_url       character_name  \
# 0   https://www.gutenberg.org/ebooks/70121.txt.utf-8            Graziella
# 1   https://www.gutenberg.org/ebooks/32646.txt.utf-8  Contos Phantasticos
# 2   https://www.gutenberg.org/ebooks/32646.txt.utf-8  Contos Phantasticos
# 3   https://www.gutenberg.org/ebooks/35073.txt.utf-8       Maria do Carmo
# 4   https://www.gutenberg.org/ebooks/35073.txt.utf-8       Maria do Carmo
# 5   https://www.gutenberg.org/ebooks/70121.txt.utf-8            Graziella
# 6   https://www.gutenberg.org/ebooks/32646.txt.utf-8  Contos Phantasticos
# 7   https://www.gutenberg.org/ebooks/32646.txt.utf-8  Contos Phantasticos
# 8   https://www.gutenberg.org/ebooks/35073.txt.utf-8       Maria do Carmo
# 9   https://www.gutenberg.org/ebooks/35073.txt.utf-8       Maria do Carmo
# 10  https://www.gutenberg.org/ebooks/68807.txt.utf-8   Gervasio Vila-Nova
# 11  https://www.gutenberg.org/ebooks/68807.txt.utf-8   Gervasio Vila-Nova
# 12  https://www.gutenberg.org/ebooks/68807.txt.utf-8   Gervasio Vila-Nova
# 13  https://www.gutenberg.org/ebooks/68807.txt.utf-8   Gervasio Vila-Nova
# 14  https://www.gutenberg.org/ebooks/68807.txt.utf-8   Gervasio Vila-Nova
# 15  https://www.gutenberg.org/ebooks/68807.txt.utf-8   Gervasio Vila-Nova
# 16  https://www.gutenberg.org/ebooks/68807.txt.utf-8   Gervasio Vila-Nova
# 17  https://www.gutenberg.org/ebooks/68807.txt.utf-8   Gervasio Vila-Nova
# 18  https://www.gutenberg.org/ebooks/68807.txt.utf-8   Gervasio Vila-Nova
# 19  https://www.gutenberg.org/ebooks/68807.txt.utf-8   Gervasio Vila-Nova
#
#                                      character_resume  \
# 0   Graziella é uma mulher melancólica, sensível e...
# 1   Contos Phantasticos é um trabalho generoso e a...
# 2   Contos Phantasticos é um trabalho generoso e a...
# 3   Maria do Carmo é uma mulher de trinta anos, ca...
# 4   Maria do Carmo é uma mulher de trinta anos, ca...
# 5   Graziella é uma mulher melancólica, sensível e...
# 6   Contos Phantasticos é um trabalho generoso e a...
# 7   Contos Phantasticos é um trabalho generoso e a...
# 8   Maria do Carmo é uma mulher de trinta anos, ca...
# 9   Maria do Carmo é uma mulher de trinta anos, ca...
# 10  Gervasio Vila-Nova é um artista carismático e ...
# 11  Gervasio Vila-Nova é um artista carismático e ...
# 12  Gervasio Vila-Nova é um artista carismático e ...
# 13  Gervasio Vila-Nova é um artista carismático e ...
# 14  Gervasio Vila-Nova é um artista carismático e ...
# 15  Gervasio Vila-Nova é um artista carismático e ...
# 16  Gervasio Vila-Nova é um artista carismático e ...
# 17  Gervasio Vila-Nova é um artista carismático e ...
# 18  Gervasio Vila-Nova é um artista carismático e ...
# 19  Gervasio Vila-Nova é um artista carismático e ...
#
#                                               snippet  \
# 0   O conservador, com um gesto nobre, rejeitou; e...
# 1   This ebook is for the use of anyone anywhere i...
# 2   Updated editions will replace the previous one...
# 3   Maria do Carmo, curvada sobre a meza, folheia ...
# 4   MARIA DO CARMO--trinta annos, com dez de casam...
# 5   O conservador, com um gesto nobre, rejeitou; e...
# 6   This ebook is for the use of anyone anywhere i...
# 7   Updated editions will replace the previous one...
# 8   Maria do Carmo, curvada sobre a meza, folheia ...
# 9   MARIA DO CARMO--trinta annos, com dez de casam...
# 10  Perturbava o seu aspecto fisico, macerado e es...
# 11  Porêm, a verdade é que em redor da sua figura ...
# 12  Todo êle encantava as mulheres. Tanta raparigu...
# 13  Entretanto, se o examinavamos com a nossa inte...
# 14  A uma criatura como aquela não se podia ter af...
# 15  Tinha muitas relações no meio artistico o meu ...
# 16  --Sim ... não discuto isso ... você bem vê, pa...
# 17  Era uma das _scies_ de Gervasio Vila-Nova: Elo...
# 18  Ah! como era bem diferente, bem mais expontane...
# 19  Aliás, ainda hoje ignoro se o meu amigo era ou...
#
#                                                traits
# 0   ["melancólico", "sensível", "discreto", "tímid...
# 1   ["generoso", "altruísta", "responsável", "ético"]
# 2   ["perfeccionista", "metódico", "responsável", ...
# 3                                 ["vaidoso", "frio"]
# 4   ["vaidoso", "curioso", "misterioso", "manipula...
# 5   ["melancólico", "sensível", "discreto", "tímid...
# 6   ["generoso", "altruísta", "responsável", "ético"]
# 7   ["perfeccionista", "metódico", "responsável", ...
# 8                                 ["vaidoso", "frio"]
# 9   ["vaidoso", "curioso", "misterioso", "manipula...
# 10                                     ["misterioso"]
# 11                      ["carismático", "misterioso"]
# 12            ["carismático", "orgulhoso", "vaidoso"]
# 13  ["criativo", "inconsequente", "corajoso", "dra...
# 14                        ["criativo", "carismático"]
# 15                                    ["carismático"]
# 16  ["temperamental", "inovador", "rebelde", "impu...
# 17  ["inovador", "rebelde", "dramático", "arrogant...
# 18  ["inflexível", "dramático", "rígido", "tempera...
# 19                                     ["misterioso"]

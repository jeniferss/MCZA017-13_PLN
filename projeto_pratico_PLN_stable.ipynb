# %% [markdown]
# <a href="https://colab.research.google.com/github/jeniferss/MCZA017-13_PLN/blob/main/projeto_pratico_PLN_stable.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Processamento de Linguagem Natural [2025-Q3]**
# Prof. Alexandre Donizeti Alves

# %% [markdown]
# ### **PROJETO PRÁTICO** [LangChain + Grandes Modelos de Linguagem]

# %% [markdown]
# O **PROJETO PRÁTICO** deve ser feito utilizando o **Google Colab** com uma conta sua vinculada ao Gmail. O link do seu notebook armazenado no Google Drive e o link de um repositório no GitHub devem ser enviados usando o seguinte formulário:
#
# > https://forms.gle/D4gLqP1iGgyn2hbH8
#
#
# **IMPORTANTE**: A submissão deve ser feita até o dia **07/12 (domingo)** APENAS POR UM INTEGRANTE DA EQUIPE, até às 23h59. Por favor, lembre-se de dar permissão de ACESSO IRRESTRITO para o professor da disciplina.

# %% [markdown]
# ### **EQUIPE**
#
# ---

# %% [markdown]
# **POR FAVOR, PREENCHER OS INTEGRANDES DA SUA EQUIPE:**
#
#
# **Integrante 01:**
#
# `JENIFER SOARES SOUZA           11202020219`
#
# **Integrante 02:**
#
# `JUAN PABLO MORENO OLIVEIRA     11202131494`

# %% [markdown]
# ### **GRANDE MODELO DE LINGUAGEM (*Large Language Model - LLM*)**
#
# ---

# %% [markdown]
# Cada equipe deve selecionar um Grande Modelo de Linguagem (*Large Language Model - LMM*).

# %% [markdown]
# Por favor, informe os dados do LLM selecionada:
#
# >
#
#
# **LLM**: gemini-2.5-flash
#
# >
#
# **Link para a documentação oficial**: https://docs.cloud.google.com/vertex-ai/generative-ai/docs/models/gemini/2-5-flash?hl=pt-br

# %% [markdown]
# ### **API (Opcional)**
# ---

# %% [markdown]
# Por favor, informe os dados da API selecionada:
#
# **API**: Gutendex
#
# **Site oficial**: https://gutendex.com/
#
# **Link para a documentação oficial**: Encontra-se na página inicial do Site Oficial

# %% [markdown]
# ### **DESCRIÇÃO**
# ---

# %% [markdown]
# Implementar um `notebook` no `Google Colab` que faça uso do framework **`LangChain`** (obrigatório) e de um **LLM** aplicando, no mínimo, DUAS técnicas de PLN. As técnicas podem ser aplicada em qualquer córpus obtido a partir de uma **API** ou a partir de uma página Web.
#
# O **LLM** e a **API** selecionados devem ser informados na seguinte planilha:
#
# > https://docs.google.com/spreadsheets/d/1iIUZcwnywO7RuF6VEJ8Rx9NDT1cwteyvsnkhYr0NWtU/edit?usp=sharing
#
# >
# As seguintes técnicas de PLN podem ser usadas:
#
# *   Correção Gramatical
# *   Classificação de Textos
# *   Análise de Sentimentos
# *   Detecção de Emoções
# *   Extração de Palavras-chave
# *   Tradução de Textos
# *   Sumarização de Textos
# *   Similaridade de Textos
# *   Reconhecimento de Entidades Nomeadas
# *   Sistemas de Perguntas e Respostas
# >
#
# **IMPORTANTE:** É obrigatório usar o e-mail da UFABC.

# %% [markdown]
# ### **CRITÉRIOS DE AVALIAÇÃO**
# ---

# %% [markdown]
# Serão considerados como critérios de avaliação os seguintes pontos:
#
# * Uso do framework **`LangChain`**.
#
# * Escolha e uso de um **LLM**.
#
# * Escolha e uso de uma **API** ou **Página Web**.
#
# * Projeto disponível no Github.
#
# * Apresentação (5 a 10 minutos).
#
# * Criatividade no uso do framework **`LangChain`** em conjunto com o **LLM** e a **API**.

# %% [markdown]
# **IMPORTANTE**: todo o código do notebook deve ser executado. Código sem execução não será considerado.

# %% [markdown]
# ### **IMPLEMENTAÇÃO**
# ---

# %% [markdown]
# Neste projeto, utilizamos como fonte de dados o [Projeto Gutenberg](https://www.gutenberg.org/about/), que disponibiliza obras literárias em domínio público. A partir desse acervo, selecionamos em torno de 160 livros de interesse para análise. Os livros foram filtrados conforme as suas caracteristicas literárias, removendo-se, por exemplo, documentos textuais, livros técnicos entre outros. Para integrá-los ao pipeline, realizamos o mapeamento manual dos seus respectivos *IDs* no catálogo e utilizamos a API [Gutendex](https://gutendex.com/) para recuperar os seus metadados, incluindo as URLs que fornecem o texto completo em formato **.txt**.
#
# Nosso objetivo principal foi extrair dados com qualidade suficiente para treinar um modelo multilabel capaz de classificar traços de personalidade de personagens literários, a partir dos trechos dos livros em que aparecem. Como prova de conceito para avaliar o desempenho do modelo, escolhemos os personagens da série Os Karas, de Manuel Bandeira.
#
# Abaixo segue uma breve ilustração do fluxograma de desenvolvimento do Projeto.
#
#
# <img height="1000" src="data:image/png;base64,...">

# %% [markdown]
# ##### Estimativas
#
# *Tempo para execução de cada pipeline completa*: 2-3 horas
# >
# *Custo Total (incluindo testes intermediários)*: Ainda não atualizado no portal do Google

# %% [markdown]
# #### Instalação de bibliotecas

# %%
# !pip install -U "langchain[google-genai]"
# Out:
# Requirement already satisfied: langchain[google-genai] in /usr/local/lib/python3.12/dist-packages (0.3.27)
# Collecting langchain[google-genai]
#   Downloading langchain-1.0.8-py3-none-any.whl.metadata (4.9 kB)
# Collecting langchain-core<2.0.0,>=1.0.6 (from langchain[google-genai])
#   Downloading langchain_core-1.1.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting langgraph<1.1.0,>=1.0.2 (from langchain[google-genai])
#   Downloading langgraph-1.0.3-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain[google-genai]) (2.11.10)
# Collecting langchain-google-genai (from langchain[google-genai])
#   Downloading langchain_google_genai-3.1.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.0.6->langchain[google-genai]) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.0.6->langchain[google-genai]) (0.4.43)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.0.6->langchain[google-genai]) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.0.6->langchain[google-genai]) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.0.6->langchain[google-genai]) (8.5.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.0.6->langchain[google-genai]) (4.15.0)
# Collecting langgraph-checkpoint<4.0.0,>=2.1.0 (from langgraph<1.1.0,>=1.0.2->langchain[google-genai])
#   Downloading langgraph_checkpoint-3.0.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.2 (from langgraph<1.1.0,>=1.0.2->langchain[google-genai])
#   Downloading langgraph_prebuilt-1.0.5-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.3.0,>=0.2.2 (from langgraph<1.1.0,>=1.0.2->langchain[google-genai])
#   Downloading langgraph_sdk-0.2.9-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.2->langchain[google-genai]) (3.6.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain[google-genai]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain[google-genai]) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain[google-genai]) (0.4.2)
# Collecting filetype<2.0.0,>=1.2.0 (from langchain-google-genai->langchain[google-genai])
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting google-ai-generativelanguage<1.0.0,>=0.9.0 (from langchain-google-genai->langchain[google-genai])
#   Downloading google_ai_generativelanguage-0.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai->langchain[google-genai]) (2.28.1)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in /usr/local/lib/python3.12/dist-packages (from google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai->langchain[google-genai]) (2.38.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai->langchain[google-genai]) (1.76.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai->langchain[google-genai]) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in /usr/local/lib/python3.12/dist-packages (from google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai->langchain[google-genai]) (5.29.5)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.6->langchain[google-genai]) (3.0.0)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain[google-genai])
#   Downloading ormsgpack-1.12.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: httpx>=0.25.2 in /usr/local/lib/python3.12/dist-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain[google-genai]) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in /usr/local/lib/python3.12/dist-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain[google-genai]) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.6->langchain[google-genai]) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.6->langchain[google-genai]) (2.32.4)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.6->langchain[google-genai]) (0.25.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai->langchain[google-genai]) (1.72.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai->langchain[google-genai]) (1.71.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai->langchain[google-genai]) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai->langchain[google-genai]) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai->langchain[google-genai]) (4.9.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain[google-genai]) (4.11.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain[google-genai]) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain[google-genai]) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain[google-genai]) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain[google-genai]) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.6->langchain[google-genai]) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.6->langchain[google-genai]) (2.5.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain-google-genai->langchain[google-genai]) (0.6.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain[google-genai]) (1.3.1)
# Downloading langchain_core-1.1.0-py3-none-any.whl (473 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 473.8/473.8 kB 8.0 MB/s eta 0:00:00
# Downloading langgraph-1.0.3-py3-none-any.whl (156 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 kB 9.7 MB/s eta 0:00:00
# Downloading langchain-1.0.8-py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.7/93.7 kB 4.7 MB/s eta 0:00:00
# Downloading langchain_google_genai-3.1.0-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.6/55.6 kB 2.2 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading google_ai_generativelanguage-0.9.0-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 30.1 MB/s eta 0:00:00
# Downloading langgraph_checkpoint-3.0.1-py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.2/46.2 kB 2.3 MB/s eta 0:00:00
# Downloading langgraph_prebuilt-1.0.5-py3-none-any.whl (35 kB)
# Downloading langgraph_sdk-0.2.9-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 4.1 MB/s eta 0:00:00
# Downloading ormsgpack-1.12.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (208 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.3/208.3 kB 21.5 MB/s eta 0:00:00
# Installing collected packages: filetype, ormsgpack, langgraph-sdk, langchain-core, langgraph-checkpoint, google-ai-generativelanguage, langgraph-prebuilt, langchain-google-genai, langgraph, langchain
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.80
#     Uninstalling langchain-core-0.3.80:
#       Successfully uninstalled langchain-core-0.3.80
#   Attempting uninstall: google-ai-generativelanguage
#     Found existing installation: google-ai-generativelanguage 0.6.15
#     Uninstalling google-ai-generativelanguage-0.6.15:
#       Successfully uninstalled google-ai-generativelanguage-0.6.15
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.3.27
#     Uninstalling langchain-0.3.27:
#       Successfully uninstalled langchain-0.3.27
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-generativeai 0.8.5 requires google-ai-generativelanguage==0.6.15, but you have google-ai-generativelanguage 0.9.0 which is incompatible.
# Successfully installed filetype-1.2.0 google-ai-generativelanguage-0.9.0 langchain-1.0.8 langchain-core-1.1.0 langchain-google-genai-3.1.0 langgraph-1.0.3 langgraph-checkpoint-3.0.1 langgraph-prebuilt-1.0.5 langgraph-sdk-0.2.9 ormsgpack-1.12.0

# %% [markdown]
# #### Importação de bibliotecas

# %%
import csv, nltk, spacy, json, os, joblib, re, requests, unicodedata, ast, pandas as pd, numpy as np
from google.colab import userdata
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate
from langchain_core.runnables import RunnableLambda, RunnableMap
from langchain_google_genai import ChatGoogleGenerativeAI
from pydantic import BaseModel, HttpUrl
from spacy.lang.en.stop_words import STOP_WORDS as EN_STOPWORDS

from time import sleep

from typing import List, Optional, Dict, Set

from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report, hamming_loss, f1_score, precision_recall_curve
from sklearn.calibration import CalibratedClassifierCV

from google.colab import files

from nltk.corpus import stopwords
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# #### Definição dos modelos de dados
#
# Representam os contratos dos dados recebidos pela API e enviados para a LLM, ajudando na validação das informações, e evitando erros de dados que são importantes, mas que por alguma razão estão nulos ou vazios.

# %%
class Person(BaseModel):
    name: str
    birth_year: Optional[int] = None
    death_year: Optional[int] = None


class BookMetadataInput(BaseModel):
    id: int
    title: str
    authors: List[Person]
    summaries: List[str] = []
    editors: List[Person] = []
    translators: List[Person] = []
    subjects: List[str] = []
    bookshelves: List[str] = []
    languages: List[str] = []
    copyright: Optional[bool] = None
    media_type: Optional[str] = None
    formats: Dict[str, HttpUrl]
    download_count: int


class BookMetadataOutput(BaseModel):
    title: str
    authors: List[Person]
    summaries: List[str] = []
    subjects: List[str] = []
    characters: List[str] = []
    languages: List[str] = []
    copyright: Optional[bool] = None
    media_type: Optional[str] = None
    text_url: HttpUrl


class CharacterLLMInput(BaseModel):
    book: BookMetadataOutput
    character_name: str
    snippets: Dict[int, str]

# %% [markdown]
# #### Definição de funções auxiliares
#
# Durante o desenvolvimento do projeto, funções foram utilizadas para possibilitar a aplicação de técnicas de PLN, especialmente **Reconhecimento de Entidades Nomeadas**, **Extração de Palavras-chave**, **Sumarização e Classificação de Textos**, além da própria interação com a LLM. As suas respectivas descrições estão apresentadas abaixo:
#
# `_normalize_text`: Normaliza e limpa texto em português, removendo acentos, pontuação, links, números e stopwords.
#
# `_name_tokens`: Separa o nome em tokens usando espaços e remove vazios.
#
# `_author_token_set`: Gera o conjunto de tokens de nomes de autores, já normalizados, para filtragem posterior.
#
# `_is_stop_candidate`: Verifica se um token deve ser descartado por ser stopword, vazio ou muito curto.
#
# `_strip_accents`: Remove acentos de uma string.
#
# `_split_paragraphs`: Separa o texto em parágrafos usando linhas em branco como delimitador e remove espaços extras.
#
# `extract_book_metadata`: Busca os metadados de um livro na API Gutendex e os valida no modelo de entrada.
#
# `extract_character_names`: Extrai nomes de personagens do resumo do livro usando NER, filtrando autores e candidatos irrelevantes.
#
# `enrich_books_with_characters`: Enriquece os metadados do livro com a lista de personagens detectados e a URL do texto completo.
#
# `find_relevant_paragraphs`: Localiza parágrafos onde o personagem é citado, adiciona uma janela de contexto, filtra trechos curtos e limita a quantidade usada no prompt.
#
# `build_character_llm_input`: Baixa o texto do livro, encontra trechos relevantes para o personagem e monta o contexto estruturado para a LLM.
#
# `build_prompt_from_context`: Constrói um prompt em JSON com metadados do livro, personagem alvo e trechos de texto.
#
# `process_book_characters`: Percorre os personagens do livro, monta o contexto, chama a cadeia da LLM, chama a função que monta os resultados para o dataset.
#
# `build_row_from_result`: Transforma as inferências da LLM e o contexto do personagem em linhas normalizadas de dataset e chama a função que salva os resultados para o dataset.
#
# `append_row_to_csv`: Acrescenta uma linha ao arquivo CSV do dataset.

# %%
def _normalize_name(name: str) -> str:
    name = name.strip().strip('"').strip("'").strip()
    name = re.sub(r"[’'´`]+s$", "", name)
    return name


def _normalize_text(texto: str) -> str:
    if not isinstance(texto, str):
        return ""
    stopwords_pt = set(stopwords.words("portuguese"))
    texto = unicodedata.normalize("NFKD", texto).encode("ascii", "ignore").decode("utf-8", "ignore")
    texto = texto.lower()
    texto = re.sub(r"http\S+|www\S+", " ", texto)
    texto = re.sub(r"\d+", " ", texto)
    texto = re.sub(r"[^\w\s]", " ", texto)
    texto = " ".join([t for t in texto.split() if t not in stopwords_pt])
    texto = re.sub(r"\s+", " ", texto).strip()

    return texto


def _name_tokens(name: str) -> Set[str]:
    return {t for t in re.split(r"\s+", name) if t}


def _author_token_set(authors) -> Set[str]:
    tokens = set()
    for a in authors:
        norm = _normalize_name(a.name.replace(",", " "))
        tokens.update(_name_tokens(norm))
    return tokens


def _is_stop_candidate(token_text: str) -> bool:
    if not token_text:
        return True
    if token_text.lower() in EN_STOPWORDS:
        return True
    if len(token_text) <= 2:
        return True
    return False


def _strip_accents(s: str) -> str:
    nfkd = unicodedata.normalize("NFD", s)
    return "".join(ch for ch in nfkd if unicodedata.category(ch) != "Mn")


def _split_paragraphs(text: str) -> List[str]:
    raw_paragraphs = re.split(r"\n\s*\n", text)
    return [p.strip() for p in raw_paragraphs if p.strip()]


def extract_book_metadata(book: int) -> BookMetadataInput:
    response = requests.get(f"https://gutendex.com/books/{book}")
    response.raise_for_status()

    gutendex = BookMetadataInput.model_validate(response.json())
    return gutendex


def extract_character_names(book) -> List[str]:
    text = " ".join(book.summaries or [])
    doc = nlp(text)

    author_tokens = _author_token_set(book.authors)
    raw_candidates: Set[str] = set()

    for ent in doc.ents:
        if ent.label_ != "PERSON":
            continue

        name = _normalize_name(ent.text)
        if not name:
            continue

        if _is_stop_candidate(name):
            continue

        tokens = _name_tokens(name)
        if not tokens:
            continue

        if tokens.issubset(author_tokens):
            continue

        raw_candidates.add(name)

    return sorted(raw_candidates)


def enrich_books_with_characters(book: BookMetadataInput) -> BookMetadataOutput:
    return BookMetadataOutput(
        authors=book.authors,
        title=book.title,
        summaries=book.summaries,
        subjects=book.subjects,
        characters=extract_character_names(book),
        text_url=book.formats['text/plain; charset=us-ascii']
    )


def find_relevant_paragraphs(
        paragraphs: List[str],
        character_name: str,
        window: int = 1,
        min_length: int = 80,
) -> List[str]:
    max_snippets_in_prompt = 20

    name_norm = _strip_accents(character_name).lower()
    pattern = re.compile(rf"\b{re.escape(name_norm)}\b")

    hit_indices: List[int] = []
    for i, p in enumerate(paragraphs):
        p_norm = _strip_accents(p).lower()
        if pattern.search(p_norm):
            hit_indices.append(i)

    if not hit_indices:
        return {}

    selected_indices: List[int] = []
    seen: Set[int] = set()

    for idx in hit_indices:
        start = max(0, idx - window)
        end = min(len(paragraphs), idx + window + 1)

        for j in range(start, end):
            if j not in seen:
                seen.add(j)
                selected_indices.append(j)

    selected_indices.sort()
    return {
        i: paragraphs[i].replace("\r\n", "\n").replace("\r", "")
        for i in selected_indices[:max_snippets_in_prompt] if len(paragraphs[i].strip()) >= min_length
    }


def build_character_llm_input(
        book_output: BookMetadataOutput,
        character_name: str,
        window: int = 1
) -> CharacterLLMInput:
    response = requests.get(book_output.text_url)
    response.raise_for_status()

    paragraphs = _split_paragraphs(response.text)
    snippets = find_relevant_paragraphs(
        paragraphs,
        character_name=character_name,
        window=window
    )

    return CharacterLLMInput(
        book=book_output,
        character_name=character_name,
        snippets=snippets
    )


def build_prompt_from_context(ctx: CharacterLLMInput) -> str:
    data = json.dumps({
        "metadados_livro": {
            "titulo": ctx.book.title,
            "autores": [a.model_dump() for a in ctx.book.authors],
            "assuntos": ctx.book.subjects,
            "personagens_detectados_no_resumo": ctx.book.characters
        },
        "personagem_alvo": {
            "nome": ctx.character_name
        },
        "trechos_texto": ctx.snippets
    }, ensure_ascii=False)
    return data


def process_book_characters(book: BookMetadataOutput) -> List[dict]:
    results: List[dict] = []

    for character_name in book.characters:
        try:
            if not character_name.strip:
                continue

            print(f"\n\nProcessando {character_name} para o livro {book.title}")
            ctx = build_character_llm_input(
                book_output=book,
                character_name=character_name,
                window=1,
            )

            if not book.characters:
                print(f"Nenhum personagem encontrado para o livro {book.title}")
                continue

            if not ctx.snippets:
                print(
                    f"Nenhum parágrafo encontrado personagem de nome {character_name} para o livro {book.title}")

            prompt_text = build_prompt_from_context(ctx)
            llm_output = trait_chain.invoke({"texto": prompt_text})

            results.append(
                {
                    "character_name": character_name,
                    "character_context": ctx,
                    "llm_output": llm_output,
                }
            )

            build_row_from_result(ctx, llm_output)
            sleep(1)

        except Exception as error:
            print("Falha ao extrair dados do personagem", str(error))

    return results


def build_row_from_result(ctx: CharacterLLMInput, llm_output: str) -> List[dict]:
    book = ctx.book

    authors_json = json.dumps([a.model_dump() for a in book.authors], ensure_ascii=False)
    summaries_json = json.dumps(book.summaries, ensure_ascii=False)
    subjects_json = json.dumps(book.subjects, ensure_ascii=False)
    characters_json = json.dumps(book.characters, ensure_ascii=False)

    cleaned = re.sub(r"^```(\w+)?", "", llm_output.strip())
    cleaned = re.sub(r"```$", "", cleaned).strip()

    inferences = json.loads(cleaned)["inferences"]
    resume = json.loads(cleaned)["resume"]

    results = []
    for inference in inferences:
        row = {
            "title": book.title,
            "authors": authors_json,
            "summaries": summaries_json,
            "subjects": subjects_json,
            "characters": characters_json,
            "text_url": book.text_url,
            "character_name": ctx.character_name,
            "character_resume": resume,
            "snippet": ctx.snippets.get(int(inference["id"])),
            "traits": json.dumps(inference["traits"], ensure_ascii=False),
        }

        append_row_to_csv(row)
        results.append(row)

    return results


def append_row_to_csv(row: dict, path: str = "characters_dataset.csv") -> None:
    file_exists = os.path.exists(path)

    with open(path, "a", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(f, fieldnames=row.keys())
        if not file_exists:
            writer.writeheader()
        writer.writerow(row)

# %% [markdown]
# #### Configuração para a pipeline

# %% [markdown]
# Para a técnica de NER, utilizamos a biblioteca spaCy. Esse foi o principal ponto de atrito do projeto, pois a identificação correta dos personagens é o ponto de entrada de toda a pipeline e determina a qualidade dos dados, tanto em diversidade de amostras quanto em redução de redundância.
#
# Como os resumos dos livros estavam em inglês, os pacotes em inglês apresentaram desempenho melhor na detecção de entidades. Ainda assim, eles não foram bons para identificar nomes brasileiros. O pacote em português (**pt-core-news**) mostrou resultados piores, classificando frases inteiras como nomes próprios.
#
# Uma alternativa seria extrair nomes diretamente do texto completo dos livros, identificando, por exemplo, padrões de repetição de nomes e pronomes. No entanto, isso exigiria processar o texto todo em batches, o que aumentaria significativamente a complexidade da pipeline, que, neste momento, não se justificava.
#
# Baseado nos testes realizados, a melhor opção foi utilizar o pacote **en_core_web_sm**, que apresentou o resultado mais consistente para os resumos disponíveis.
#
# Exemplo pacote brasileiro:
#
# ![image.png](data:image/png;base64,...)
#
#
# Outro ponto importante foi a limitação das “classes”, os chamados `traits` no projeto, tanto no prompt quanto no formato de retorno. Essa restrição foi necessária para garantir que o modelo, posteriormente, operasse com um conjunto controlado de possibilidades e evitando a necessidade de tratar variações dos adjetivos (por exemplo, “bonito” vs. “bonita”).
#
# Também foi preciso refinar quais adjetivos seriam incluídos. Quando o conjunto era amplo, alguns `traits` apareciam raramente, enquanto outros causavam `overfitting`, por serem descritivos demais e aplicáveis a qualquer personagem.

# %%
nlp = spacy.load("en_core_web_sm")

GOOGLE_API_KEY = userdata.get('GOOGLE_API_KEY')
print(f"\n\nGOOGLE_API_KEY está vazia." if GOOGLE_API_KEY is None else "")

llm_model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    google_api_key=GOOGLE_API_KEY,
    temperature=0.0,
)

trait_prompt = PromptTemplate(
    input_variables=["texto"],
    template=("""
        Você é um analista especializado em perfis de personagens literários. Com base EXCLUSIVAMENTE nos trechos fornecidos abaixo, produza um JSON com inferências de personalidade. Regras obrigatórias:
        - A saída deve conter apenas JSON. Não inclua explicações.
        - O JSON final deve ter exatamente as chaves:
        - "inferences": lista de objetos.
        - "resume": um resumo com NO MÁXIMO 200 caracteres EM PORTUGUÊS BARSILEIRO sobre quem é o personagem com base EM TODOS OS TRECHOS enviado no contexto como "trechos_texto".
        - Cada objeto dentro de "inferences" deve seguir esta estrutura:
        - "id": o mesmo id recebido na entrada, correspondente ao trecho analisado.
        - "traits": lista de adjetivos que descrevem a personalidade detectada NO TRECHO.
        - Você deve retirar apenas traits claramente justificáveis pelo trecho.
        - Se não houver traits relevantes, NÃO inclua esse item na lista "inferences".
        - Todos os adjetivos devem ser:
        - em PORTUGUÊS BRASILEIRO,
        - no gênero masculino,
        - escolhidos APENAS desta lista:
         "astuto","inteligente","misterioso","impulsivo","determinado",
          "corajoso","leal","observador","protetor","curioso",
          "arrogante","orgulhoso","cínico","vaidoso","ambicioso",
          "teimoso","dominador","controlador","inflexível","desconfiado",
          "gentil","bondoso","generoso","altruísta","empático",
          "frio","calculista","rígido","prudente","precavido",
          "racional","sarcástico","irônico","questionador","criativo",
          "trabalhador","resiliente","responsável","conservador","pragmático",
          "agressivo","hostil","vingativo","cruel","mentiroso",
          "covarde","irresponsável","negligente","egoísta","maldoso",
        - Contexto: \n {texto}
    """),
)

trait_chain = trait_prompt | llm_model | StrOutputParser()

# %% [markdown]
# #### Definição da pipeline
#
# o LangChain é uma biblioteca que facilita a orquestração de componentes que usam LLMs. No presnete trabalho, funções Python em foram encadeadas e tratadas como Runnables formando pipelines: o primeiro runnable recebe um dicionário com book_id e busca os metadados do livro, o segundo enriquece esses metadados com informações de personagens e o pipeline completo acrescenta um passo final que processa/caracteriza os personagens.

# %%
fetch_metadata_runnable = RunnableLambda(
    lambda inp: extract_book_metadata(inp["book_id"])
)

enrich_with_characters_runnable = RunnableLambda(
    lambda book: enrich_books_with_characters(book)
)

book_metadata_pipeline = fetch_metadata_runnable | enrich_with_characters_runnable
full_book_pipeline = book_metadata_pipeline | RunnableLambda(process_book_characters)

# %% [markdown]
# #### Execução da pipeline

# %%
if __name__ == "__main__":

    path = 'final_ptbr_fiction.csv'
    if os.path.exists(path):
        df = pd.read_csv(path)
        book_ids = df['id']
    else:
        print("Arquivo não encontrado, usando um ID de teste.")
        book_ids = [69187]

    for book_id in book_ids:
        try:
            pipeline_input = {"book_id": book_id}
            results = full_book_pipeline.invoke(pipeline_input)

            for index, item in enumerate(results):
                print(f"\n\nResultado {index + 1}:")
                print(item)

                sleep(5)
        except Exception as error:
            print("Falha ao executar extração de dados para o livro", str(error))
# Out:
# Processando Graziella para o livro A capital federal (impressões de um sertanejo)
#
#
# Processando Sertanejo para o livro A capital federal (impressões de um sertanejo)
#
#
# Resultado 1:
#
#
# Processando Contos Phantasticos para o livro Contos Phantasticos: segunda edição correcta e ampliada
#
#
# Resultado 1:
# {'character_name': 'Contos Phantasticos', 'character_context': CharacterLLMInput(book=BookMetadataOutput(title='Contos Phantasticos: segunda edição correcta e ampliada', authors=[Person(name='Braga, Teófilo', birth_year=1843, death_year=1924)], summaries=['"Contos Phantasticos" by Teófilo Braga is a collection of short stories written in the late 19th century. This work explores themes of passion, melancholy, and existential contemplation, presenting characters deeply immersed in their own emotional struggles and the broader human experience. The stories blend poetic language with a philosophical undertone, drawing readers into the internal conflicts of its characters.  The opening of "Contos Phantasticos" introduces a reflective preface where Braga revisits his earlier works with both nostalgia and critique. He recounts the personal struggles faced during the creation of these stories, mingling memories with literary analysis. The narrative then shifts to portray a character, presumably a young woman, enveloped in a profound sadness despite her beauty and youth, hinting at deeper existential themes. The tone is introspective, evoking a sense of longing and the complexities of love, ultimately setting the stage for the intricate and emotionally charged tales to follow. (This is an automatically generated summary.)'], subjects=['Fiction', 'Short stories, Portuguese'], characters=['Contos Phantasticos'], languages=[], copyright=None, media_type=None, text_url=HttpUrl('https://www.gutenberg.org/ebooks/32646.txt.utf-8')), character_name='Contos Phantasticos', snippets={1: 'This ebook is for the use of anyone anywhere in the United States and\nmost other parts of the world at no cost and with almost no restrictions\nwhatsoever. You may copy it, give it away or re-use it under the terms\nof the Project Gutenberg License included with this ebook or online\nat www.gutenberg.org. If you are not located in the United States,\nyou will have to check the laws of the country where you are located\nbefore using this eBook.', 6: 'Credits: Produced by Pedro Saborano and the Online Distributed\n        Proofreading Team at https://www.pgdp.net (This book was\n        produced from scanned images of public domain material\n        from the Google Print project.)', 8: 'Produced by Pedro Saborano and the Online Distributed\nProofreading Team at https://www.pgdp.net (This book was\nproduced from scanned images of public domain material\nfrom the Google Print project.)', 654: 'Updated editions will replace the previous one—the old editions will\nbe renamed.'}), 'llm_output': '```json\n{\n  "inferences": [],\n  "resume": "Contos Phantasticos é um ebook de domínio público, produzido por uma equipe, disponível gratuitamente sob licença específica, com edições atualizadas e regras de uso. Não há informações sobre sua personalidade."\n}\n```'}
#
#
# Processando Maria do Carmo para o livro Flirts
#
#
# Resultado 1:
# {'character_name': 'Maria do Carmo', 'character_context': CharacterLLMInput(book=BookMetadataOutput(title='Flirts', authors=[Person(name='Vasconcellos, Henrique de', birth_year=1876, death_year=1924)], summaries=['"Flirts" by Henrique de Vasconcellos is a collection of short stories written in the early 20th century. The work explores themes of love, flirtation, and social interactions, reflecting on the lives of various characters navigating romance and relationships. The stories likely feature a range of humorous and poignant exchanges between lovers and acquaintances, capturing the intricacies of human emotions.  At the start of the collection, we are introduced to a setting that resembles a flirtation school, where a professor instructs a naive student named Maria do Carmo, who seeks to learn the art of flirting to navigate her new life in Lisbon. The professor is depicted as knowledgeable yet somewhat cynical, guiding his disciple through the nuances of societal expectations and flirtation techniques. Their dialogue reveals a blend of sophistication and humor as they discuss appearance, conversation, and the nature of romantic encounters, setting the tone for the exploration of interpersonal dynamics throughout the stories. (This is an automatically generated summary.)'], subjects=['Fiction'], characters=['Maria do Carmo'], languages=[], copyright=None, media_type=None, text_url=HttpUrl('https://www.gutenberg.org/ebooks/35073.txt.utf-8')), character_name='Maria do Carmo', snippets={65: 'O PROFESSOR--Não fica mal um pouco de poesia... Falar do mar e do\nestremecimento da lua sobre as aguas inquietas, comparar-se á agua\nmovediça e infiel... Emfim são coisas para mais tarde. Vamos aos\npreliminares. Ah! Antes de mais nada: o nome de v. ex.ª?', 118: 'Maria do Carmo, curvada sobre a meza, folheia os ultimos _envois_ de\n    Paquin e Redfern. Um candieiro com um largo quebra-luz de seda e\n    rendas lança-lhe sobre o cabello uma aureola de oiro. O corpo está\n    mergulhado na penumbra. Na sala, os moveis tomam aspectos\n    fantasticos. Os espelhos teem um brilho pallido. Gonçalo, ao entrar,\n    beija a mão que Maria do Carmo lhe estende, sem levantar os olhos\n    dos papeis.', 119: 'MARIA DO CARMO--trinta annos, com dez de casamento. Sem filhos. A\n    vida passa-se-lhe em visitas, _raouts_, recéções e bailes. Alguns\n    livros da moda, recommendados por Marcel Ballot, no _Figaro_, e Jean\n    Lorrain, por curiosidade. Interessante como um enigma, ás vezes\n    perversa. Não se lhe conhece um amante, mas indicam-se muitos. Não\n    toca piano.', 120: 'GONÇALO--não tem uma branca, mas no meio da animação, ficticia,\n    vê-se um grande cançaço de viver, como se tivesse experimentado\n    tudo. Procura por toda a parte, como um _gourmet_, o manjar fino.\n    Epicurista, delicadamente depravado, como um _roué_ da Restauração,\n    ou um elegante do fim da republica romana.'}), 'llm_output': '```json\n{\n  "inferences": [\n    {\n      "id": "118",\n      "traits": [\n        "arrogante"\n      ]\n    },\n    {\n      "id": "119",\n      "traits": [\n        "curioso",\n        "misterioso",\n        "maldoso"\n      ]\n    }\n  ],\n  "resume": "Maria do Carmo é uma mulher de trinta anos, casada, sem filhos, com vida social intensa. Curiosa e misteriosa, ela mantém uma reputação intrigante, por vezes demonstrando um certo distanciamento e maldade."\n}\n```'}
#
#
# Processando Alfonso XII para o livro O Romance da Rainha Mercedes
# Nenhum parágrafo encontrado personagem de nome Alfonso XII encontrado para o livro O Romance da Rainha Mercedes
#
#
# Resultado 1:
# {'character_name': 'Alfonso XII', 'character_context': CharacterLLMInput(book=BookMetadataOutput(title='O Romance da Rainha Mercedes', authors=[Person(name='Pimentel, Alberto', birth_year=1849, death_year=1925)], summaries=['"O Romance da Rainha Mercedes" by Alberto Pimentel is a historical novel written in the late 19th century. The narrative examines the life and love of King Alfonso XII of Spain and his relationship with Maria de las Mercedes, his cousin and future queen. The book delves into themes of love, duty, and the burdens that come with royalty, while reflecting on the complexities of monarchical systems.  At the start of the novel, the author reflects on the historical evolution
# {'character_name': 'Negrão', 'character_context': CharacterLLMInput(book=BookMetadataOutput(title='Os fidalgos da Casa Mourisca: Chronica da aldeia', authors=[Person(name='Dinis, Júlio', birth_year=1839, death_year=1871)], summaries=['"Os Fidalgos da Casa Mourisca" by Júlio Dinis is a novel written in the late 19th century. It explores themes of social decline, inheritance, and the contrast between old aristocracy and new agrarian prosperity through the lives of the Negrão family, particularly focusing on the struggles of D. Luiz, the patriarch, and his two sons, Jorge and Mauricio. The story delves into their ancestral home, the Casa Mourisca, which symbolizes their faded grandeur and the challenges posed by changing socio-political landscapes.  At the start of the narrative, the reader is introduced to the historical context of Portugal and the local folklore that surrounds the characters, specifically the notion of "mouras encantadas." The narrative quickly shifts to the depiction of the Casa Mourisca, highlighting its dilapidated state and the burdens of the Negrão family. D. Luiz, having returned from a diplomatic career, is shown grappling with family tragedies and political tensions. His sons represent differing attitudes towards their legacy; Jorge is introspective and concerned with the family\'s decline, whereas Mauricio is more carefree and focused on societal pleasures. As Jorge observes the flourishing Herdade nearby, he begins to reflect on saving their family estate, setting the stage for potential conflict and character development. (This is an automatically generated summary.)'], subjects=['Love stories', 'Nobility -- Portugal -- Fiction', 'Portugal -- Fiction'], characters=['D. Luiz', 'Jorge', 'Mauricio', 'Negrão'], languages=[], copyright=None, media_type=None, text_url=HttpUrl('https://www.gutenberg.org/ebooks/16428.txt.utf-8')), character_name='Negrão', snippets={230: "--É porque o dono d'elles é o snr. D. Luiz Negrão de Villar de Corvos, o\nfidalgo da Casa Mourisca, como por aqui lhe chamamos todos."}), 'llm_output': '```json\n{\n  "inferences": [],\n  "resume": "D. Luiz Negrão de Villar de Corvos é um fidalgo, conhecido como o fidalgo da Casa Mourisca, e proprietário de bens."\n}\n```'}
#
#
# Processando Emilio para o livro O Arrependimento
#
#
# Processando Roberto para o livro O Arrependimento
#
#
# Resultado 1:
# {'character_name': 'Emilio', 'character_context': CharacterLLMInput(book=BookMetadataOutput(title='O Arrependimento', authors=[Person(name='Castelo Branco, Camilo', birth_year=1825, death_year=1890)], summaries=['"O Arrependimento" by Camilo Castelo Branco is a novel written in the mid-19th century. This work explores themes of morality, redemption, and the complexity of human nature, focusing on the emotional and psychological struggles of its characters as they navigate the consequences of their choices.  The narrative revolves around Emilio da Cunha and his younger nephew, Roberto. After Emilio takes in Roberto following the demise of his brother, he hopes to guide him toward a better path. However, Roberto\'s negative influences lead him astray, resulting in a life filled with crime and despair. The story takes a turn when Roberto, after a moment of realization of his misdeeds, embarks on a journey to redeem himself, striving to earn back the trust and forgiveness of his uncle and cousin, Valentina. The novel ultimately emphasizes the potential for regeneration and the significance of compassion and understanding in overcoming past mistakes. (This is an automatically generated summary.)'], subjects=['Portuguese fiction -- 19th century', 'Short stories, Portuguese'], characters=['Emilio', 'Roberto'], languages=[], copyright=None, media_type=None, text_url=HttpUrl('https://www.gutenberg.org/ebooks/23346.txt.utf-8')), character_name='Emilio', snippets={26: '--Emilio da Cunha era o mais velho de tres irmãos, dos quaes, o mais\nnovo, vivia ha muitos annos no Rio de Janeiro, onde tinha alcançado\nfortuna. O segundo nunca deixou o Porto, sendo sempre infeliz nos seus\ncommettimentos e especulações. Emilio da Cunha, á custa de muito\ntrabalho e economias, pôde alcançar uma fortunasinha, que lhe permittia\nesperar com socego, o momento de descançar da vida laboriosa em que\ntinha vivido.', 27: "Uma quarta pessoa completava esta familia, que era uma irmã, que tendo\nseguido seu marido á India, para onde elle tinha sido despachado, e não\nvindo nenhum d'elles a figurar n'esta minha historia, não lh'os\nrecordarei mais.", 28: "Aconteceu que o irmão de Emilio da Cunha, que residia no Porto, por uma\nd'estas catastrophes que occasionam os jogos de bolsa, falliu. Teve tal\nsentimento por este facto, que falleceu tres dias depois, atacado d'uma\nfebre cerebral. A herança, que deixou, foram dividas e um filho.", 29: 'Emilio da Cunha, que tinha um coração bondoso, e um caracter\npundonoroso, para que a memoria de seu irmão não ficasse deshonrada,\ncomprometteu-se a pagar as dividas e recolheu em sua casa o filho para\nlhe substituir o pai, que tinha perdido; procedimento louvavel, e digno\nde se admirar, sabendo-se que elle tinha uma filha, para quem, passados\nquatro ou cinco annos tinha a procurar um casamento vantajoso.', 30: "Roberto, se chamava o sobrinho de Emilio da Cunha, tinha já 15 annos\nd'idade, mas o pai, inteiramente entregue ás especulações, e aos\ncuidados, que ellas trazem comsigo, descuidou completamente a sua\neducação, por isso o seu retrato moral, n'esta occasião, nada tinha de\nvantajoso; o espirito tinha-o completamente inculto; as noções que\npossuia do justo e do injusto eram as mais erroneas e disparatadas; o\nrespeito aos direitos d'outrem era para elle uma invenção estupida dos\nhomens, condemnada pela natureza, e a verdadeira liberdade consistia em\nfazer o mal impunemente. Se algum bom instincto, ou algum vislumbre de\nvirtude, existia no coração de Roberto, ainda estava em embryão, por que\nse não tinha demonstrado. Quantas e quantas vezes, em quanto que o pai,\ncego pelas especulações, concentrava todas as suas faculdades\nintellectuaes na realisação d'um impossivel, não deixou Roberto de ir ao\ncollegio, fazendo o que em termo escolar, se chama _gazear_, e gastava\nas horas d'estudo em andar a vagabundear pelos campos e praças. D'ahi\nproveio o tomar relações com meia duzia de garotos, ou vadios,\npermitta-m ...
#
#
# Resultado 2:
# {'character_name': 'Roberto', 'character_context': CharacterLLMInput(book=BookMetadataOutput(title='O Arrependimento', authors=[Person(name='Castelo Branco, Camilo', birth_year=1825, death_year=1890)], summaries=['"O Arrependimento" by Camilo Castelo Branco is a novel written in the mid-19th century. This work explores themes of morality, redemption, and the complexity of human nature, focusing on the emotional and psychological struggles of its characters as they navigate the consequences of their choices.  The narrative revolves around Emilio da Cunha and his younger nephew, Roberto. After Emilio takes in Roberto following the demise of his brother, he hopes to guide him toward a better path. However, Roberto\'s negative influences lead him astray, resulting in a life filled with crime and despair. The story takes a turn when Roberto, after a moment of realization of his misdeeds, embarks on a journey to redeem himself, striving to earn back the trust and forgiveness of his uncle and cousin, Valentina. The novel ultimately emphasizes the potential for regeneration and the significance of compassion and understanding in overcoming past mistakes. (This is an automatically generated summary.)'], subjects=['Portuguese fiction -- 19th century', 'Short stories, Portuguese'], characters=['Emilio', 'Roberto'], languages=[], copyright=None, media_type=None, text_url=HttpUrl('https://www.gutenberg.org/ebooks/23346.txt.utf-8')), character_name='Roberto', snippets={29: 'Emilio da Cunha, que tinha um coração bondoso, e um caracter\npundonoro
ly mingle and dance amidst a lavish atmosphere. As the celebration unfolds, we are introduced to the Viscondessa herself, described as an exquisite and troubled beauty caught in a complicated romance with a young man named Alfredo. Their flirtations are abruptly interrupted by another man, filled with jealousy and rage, threatening Alfredo with a dagger, thus igniting the tension of unrequited love and rivalry that permeates the story. This opening lays the groundwork for exploring the Viscondessa\'s inner turmoil and the societal expectations placed upon her. (This is an automatically generated summary.)'], subjects=['Portuguese fiction -- 19th century'], characters=['Alfredo', 'Viscondessa'], languages=[], copyright=None, media_type=None, text_url=HttpUrl('https://www.gutenberg.org/ebooks/24710.txt.utf-8')), character_name='Alfredo', snippets={40: '--E acredita a senhora viscondessa, que eu realmente lhe podesse ser\naffeiçoado nas condições em que me acho?', 46: 'E continuou a fallar para Alfredo, que, a longos passos, percorria a\nsala de um a outro extremo.', 52: "Defronte d'elle, e ameaçando-o com um punhal, estava um rapaz, cheio de\nfebre, de odio e de vingança.", 53: '--Ouvi tudo--exclamou o intruso. Ou tu me promettes nunca amar a\nviscondessa, ou eu te assassino aqui, como um miseravel que és.', 54: "--Nunca!...--vociferou Alfredo, arrancando-lhe o punhal da mão. Primeiro\ncahirás tu, desgraçado. Já, já fora d'esta casa...........................\n..........................................................................", 55: 'Este incidente, como é natural, perturbou a quadrilha, que então se\ndançava. Acorreram todos. Os dois contendores haviam desapparecido da\nsaleta.', 105: "Representava-se a _Vida de um rapaz_ pobre n'essa noite. A Viscondessa\nadmiravel de bellesa e encanto, provocava de continuo os binoculos das\nplateias.", 106: 'No fim do 3.^o acto a porta da frisa abriu-se. Era Alfredo que entrava.\nA Viscondessa sorriu-se.'}), 'llm_output': '```json\n{\n  "inferences": [\n    {\n      "id": "40",\n      "traits": [\n        "questionador",\n        "pragmático"\n      ]\n    },\n    {\n      "id": "54",\n      "traits": [\n        "inflexível",\n        "determinado",\n        "corajoso",\n        "impulsivo",\n        "agressivo",\n        "dominador"\n      ]\n    }\n  ],\n  "resume": "Alfredo é um homem questionador e pragmático, mas que se revela corajoso, determinado e inflexível diante de ameaças. Ele age de forma impulsiva e agressiva para dominar situações de conflito."\n}\n```'}
#
#
# Resultado 2:
# {'character_name': 'Viscondessa', 'character_context': CharacterLLMInput(book=BookMetadataOutput(title='A Senhora Viscondessa', authors=[Person(name='Lima, S. de Magalhães (Sebastião de Magalhães)', birth_year=1850, death_year=1928)], summaries=['"A Senhora Viscondessa" by S. de Magalhães Lima is a romantic novel written in the late 19th century. The story revolves around a fashionable woman, the Viscondessa, and her entangled relationships and affairs amidst the backdrop of high society in Portugal. The narrative introduces themes of desire, jealousy, and social struggles as it sets the stage for intricate character interactions.  At the start of the novel, the scene is set at a grand ball hosted by the Viscondessa at her palatial home, where guests elegantly mingle and dance amidst a lavish atmosphere. As the celebration unfolds, we are introduced to the Viscondessa herself, described as an exquisite and troubled beauty caught in a complicated romance with a young man named Alfredo. Their flirtations are abruptly interrupted by another man, filled with jealousy and rage, threatening Alfredo with a dagger, thus igniting the tension of unrequited love and rivalry that permeates the story. This opening lays the groundwork for exploring the Viscondessa\'s inner turmoil and the societal expectations placed upon her. (This is an automatically generated summary.)'], subjects=['Portuguese fiction -- 19th century'], characters=['Alfredo', 'Viscondessa'], languages=[], copyright=None, media_type=None, text_url=HttpUrl('https://www.gutenberg.org/ebooks/24710.txt.utf-8')), character_name='Viscondessa', snippets={1: 'This ebook is for the use of anyone anywhere in the United States and\nmost other parts of the world at no cost and with almost no restrictions\nwhatsoever. You may copy it, give it away or re-use it under the terms\nof the Project Gutenberg License included with this ebook or online\nat www.gutenberg.org. If you are not located in the United States,\nyou will have to check the laws of the country where you are located\nbefore using this eBook.', 24: 'Á porta do palacete param trens sem conta. Descem os convivas,\nprofusamente almiscarados.', 30: 'Umas plantas exoticas, orientaes, adornam o espaço ladrilhado das\njanellas de sacada.', 31: "Entra a viscondessa na sala. Os grupos cessam de falar. Em redor d'ella\ntudo se apinha, tudo se confunde, tudo se baralha.", 32: "A valsa recomeça. Nos espelhos de crystal reflectem-se as estranhas\nimagens, que, n'esta noite, povoam o salão. Sobre as piscinas de marmore\ndebruçam-se as avesinhas artificiaes--pobres avesinhas implumes feitas\nde pedra e de calcareo.", 39: 'Os creados serviram o chá. Na varanda fumavam e conversavam os\ncavalheiros. Algumas senhoras refaziam a sua _toilette_, em parte\ndesfeita pelos ardores da dança.'}), 'llm_output': '```json\n{\n  "inferences": [\n    {\n      "id": "31",\n      "traits": [\n        "dominador",\n        "misterioso"\n      ]\n    }\n  ],\n  "resume": "A Viscondessa é uma figura de forte presença, cuja entrada em um ambiente causa grande impacto, dominando a atenção e gerando um certo mistério ou confusão entre os presentes."\n}\n```'}
#
#
# Processando Margarida para o livro A nossa Gente
#
#
# Processando Nossa Gente para o livro A nossa Gente
#
#
# Resultado 1:
# {'character_name': 'Margarida', 'character_context': CharacterLLMInput(book=BookMetadataOutput(title='A nossa Gente', authors=[Person(name='Queiroz, Teixeira de', birth_year=1848, death_year=1919)], summaries=['"A Nossa Gente" by Teixeira de Queiroz is a novel written in the late 19th century. The story begins with a focus on a character named Margarida, exploring her early life, relationships with her caretakers, and the physical and emotional struggles she faces as she grows up. Themes of innocence, maternal love, and the complexities of childhood are likely woven throughout the narrative.  At the start of the novel, the author introduces Margarida as a child who is predominantly cared for by her nurse, Antonia. The narrative captures the early moments of her life characterized by simplicity and innocence, as well as her troubling experiences with pain and illness during her childhood. As she grows older, her character displays a vivid emotional range, marked by phases of joy and turmoil, foreshadowing the challenges she will face. The opening evokes a sense of compassion for the child and hints at the dramatic events that will shape her destiny. (This is an automatically generated summary.)'], subjects=['Portuguese fiction -- 19th century', 'Short stories, Portuguese'], characters=['Margarida', 'Nossa Gente'], languages=[], copyright=None, media_type=None, text_url=HttpUrl('https://www.gutenberg.org/ebooks/67561.txt.utf-8')), character_name='Margarida', snippets={44: 'LISBOA\n             Typographia da Parceria Antonio Maria Pereira\n                           _11—Apostolos—11_\n                                  1899', 48: "Era adoravel no berço pela sua tranquillidade feliz: esse primeiro anno\nde exist
67561.txt.utf-8')), character_name='Nossa Gente', snippets={1: 'This ebook is for the use of anyone anywhere in the United States and\nmost other parts of the world at no cost and with almost no restrictions\nwhatsoever. You may copy it, give it away or re-use it under the terms\nof the Project Gutenberg License included with this ebook or online\nat www.gutenberg.org. If you are not located in the United States,\nyou will have to check the laws of the country where you are located\nbefore using this eBook.', 7: 'Credits: Pedro Saborano and the Online Distributed Proofreading Team at https://www.pgdp.net (This book was produced from scanned images of public domain material from the Google Books project.)', 12: '=Parceria Antonio Maria Pereira=|(LIVRARIA-EDITORA)|_50, 52—Rua\n       Augusta—52, 54_', 40: 'POR\n                          TEIXEIRA DE QUEIROZ\n                            (_Bento Moreno_)', 466: '—Durante estes ultimos vinte annos carteamo-nos sobejamente. Os nossos\ncorações uniram-se em bellas paginas, como só elle as sabia escrever.', 467: "—Não o apreciei debaixo d'esse ponto de vista, mas sim na convivencia.\nEra um homem altamente religioso e não d'esses modernos que chasqueiam\ndos bons principios. Uma festa, aqui popularissima, á Senhora do Regaço,\ne que elle todos os annos fazia á sua custa, com pompa e luzimento,\ndera-lhe entre a nossa gente verdadeira nomeada de bom catholico. N'este\nponto julgo adivinhar que v. s.ª não quebrará a tradicção...", 468: 'O dr. Gama concentrou-se. Tomou aspecto reflexivo, enguliu em sêcco duas\nvezes.'}), 'llm_output': '```json\n{\n  "inferences": [\n    {\n      "id": "467",\n      "traits": [\n        "observador",\n        "conservador"\n      ]\n    }\n  ],\n  "resume": "Nossa Gente é a comunidade que observa e julga as ações de seus membros, valorizando a tradição e os bons princípios, especialmente a devoção religiosa."\n}\n```'}

# %% [markdown]
# #### Modelo de Classificação Multilabel

# %% [markdown]
# ##### Análise Inicial
#
# Dada a extração de dados, o passo seguinte foi realizar o tratamento e a normalização dos possíveis resquícios presentes no resultado retornado. Para isso, foi feita uma breve análise exploratória de quais e quantos dados foram retornados, e aplicado um processo de padronização dos `traits`, incluindo a separação de valores agrupados por delimitadores não padronizados.
#
# Também foi realizada a limpeza `snippets` vazios. O objetivo final dessa etapa era garantir uma relação 1:1 entre cada `snippet` e seu respectivo conjunto de `traits`.

# %%
filepath = "characters_dataset.csv"
files.download(filepath)
pd.read_csv(filepath).head(20)
# Out:
#                                              title  \
# 0   A capital federal (impressões de um sertanejo)
# 1   A capital federal (impressões de um sertanejo)
# 2   A capital federal (impressões de um sertanejo)
# 3   A capital federal (impressões de um sertanejo)
# 4   A capital federal (impressões de um sertanejo)
# 5   A capital federal (impressões de um sertanejo)
# 6   A capital federal (impressões de um sertanejo)
# 7                                           Flirts
# 8                                           Flirts
# 9                A confissão de Lucio,: Narrativa.
# 10               A confissão de Lucio,: Narrativa.
# 11               A confissão de Lucio,: Narrativa.
# 12               A confissão de Lucio,: Narrativa.
# 13               A confissão de Lucio,: Narrativa.
# 14               A confissão de Lucio,: Narrativa.
# 15               A confissão de Lucio,: Narrativa.
# 16               A confissão de Lucio,: Narrativa.
# 17               A confissão de Lucio,: Narrativa.
# 18               A confissão de Lucio,: Narrativa.
# 19               A confissão de Lucio,: Narrativa.
#
#                                               authors  \
# 0   [{"name": "Coelho Netto, Henrique", "birth_yea...
# 1   [{"name": "Coelho Netto, Henrique", "birth_yea...
# 2   [{"name": "Coelho Netto, Henrique", "birth_yea...
# 3   [{"name": "Coelho Netto, Henrique", "birth_yea...
# 4   [{"name": "Coelho Netto, Henrique", "birth_yea...
# 5   [{"name": "Coelho Netto, Henrique", "birth_yea...
# 6   [{"name": "Coelho Netto, Henrique", "birth_yea...
# 7   [{"name": "Vasconcellos, Henrique de", "birth_...
# 8   [{"name": "Vasconcellos, Henrique de", "birth_...
# 9   [{"name": "Sá-Carneiro, Mário de", "birth_year...
# 10  [{"name": "Sá-Carneiro, Mário de", "birth_year...
# 11  [{"name": "Sá-Carneiro, Mário de", "birth_year...
# 12  [{"name": "Sá-Carneiro, Mário de", "birth_year...
# 13  [{"name": "Sá-Carneiro, Mário de", "birth_year...
# 14  [{"name": "Sá-Carneiro, Mário de", "birth_year...
# 15  [{"name": "Sá-Carneiro, Mário de", "birth_year...
# 16  [{"name": "Sá-Carneiro, Mário de", "birth_year...
# 17  [{"name": "Sá-Carneiro, Mário de", "birth_year...
# 18  [{"name": "Sá-Carneiro, Mário de", "birth_year...
# 19  [{"name": "Sá-Carneiro, Mário de", "birth_year...
#
#                                             summaries  \
# 0   ["\"A Capital Federal (Impressões de um Sertan...
# 1   ["\"A Capital Federal (Impressões de um Sertan...
# 2   ["\"A Capital Federal (Impressões de um Sertan...
# 3   ["\"A Capital Federal (Impressões de um Sertan...
# 4   ["\"A Capital Federal (Impressões de um Sertan...
# 5   ["\"A Capital Federal (Impressões de um Sertan...
# 6   ["\"A Capital Federal (Impressões de um Sertan...
# 7   ["\"Flirts\" by Henrique de Vasconcellos is a ...
# 8   ["\"Flirts\" by Henrique de Vasconcellos is a ...
# 9   ["\"A Confissão de Lucio: Narrativa\" by Mário...
# 10  ["\"A Confissão de Lucio: Narrativa\" by Mário...
# 11  ["\"A Confissão de Lucio: Narrativa\" by Mário...
# 12  ["\"A Confissão de Lucio: Narrativa\" by Mário...
# 13  ["\"A Confissão de Lucio: Narrativa\" by Mário...
# 14  ["\"A Confissão de Lucio: Narrativa\" by Mário...
# 15  ["\"A Confissão de Lucio: Narrativa\" by Mário...
# 16  ["\"A Confissão de Lucio: Narrativa\" by Mário...
# 17  ["\"A Confissão de Lucio: Narrativa\" by Mário...
# 18  ["\"A Confissão de Lucio: Narrativa\" by Mário...
# 19  ["\"A Confissão de Lucio: Narrativa\" by Mário...
#
#                                              subjects  \
# 0   ["Brazilian literature", "Romance fiction, Bra...
# 1   ["Brazilian literature", "Romance fiction, Bra...
# 2   ["Brazilian literature", "Romance fiction, Bra...
# 3   ["Brazilian literature", "Romance fiction, Bra...
# 4   ["Brazilian literature", "Romance fiction, Bra...
# 5   ["Brazilian literature", "Romance fiction, Bra...
# 6   ["Brazilian literature", "Romance fiction, Bra...
# 7                                         ["Fiction"]
# 8                                         ["Fiction"]
# 9              ["Portuguese fiction -- 20th century"]
# 10             ["Portuguese fiction -- 20th century"]
# 11             ["Portuguese fiction -- 20th century"]
# 12             ["Portuguese fiction -- 20th century"]
# 13             ["Portuguese fiction -- 20th century"]
# 14             ["Portuguese fiction -- 20th century"]
# 15             ["Portuguese fiction -- 20th century"]
# 16             ["Portuguese fiction -- 20th century"]
# 17             ["Portuguese fiction -- 20th century"]
# 18             ["Portuguese fiction -- 20th century"]
# 19             ["Portuguese fiction -- 20th century"]
#
#                          characters  \
# 0        ["Graziella", "Sertanejo"]
# 1        ["Graziella", "Sertanejo"]
# 2        ["Graziella", "Sertanejo"]
# 3        ["Graziella", "Sertanejo"]
# 4        ["Graziella", "Sertanejo"]
# 5        ["Graziella", "Sertanejo"]
# 6        ["Graziella", "Sertanejo"]
# 7                ["Maria do Carmo"]
# 8                ["Maria do Carmo"]
# 9   ["Gervasio Vila-Nova", "Lucio"]
# 10  ["Gervasio Vila-Nova", "Lucio"]
# 11  ["Gervasio Vila-Nova", "Lucio"]
# 12  ["Gervasio Vila-Nova", "Lucio"]
# 13  ["Gervasio Vila-Nova", "Lucio"]
# 14  ["Gervasio Vila-Nova", "Lucio"]
# 15  ["Gervasio Vila-Nova", "Lucio"]
# 16  ["Gervasio Vila-Nova", "Lucio"]
# 17  ["Gervasio Vila-Nova", "Lucio"]
# 18  ["Gervasio Vila-Nova", "Lucio"]
# 19  ["Gervasio Vila-Nova", "Lucio"]
#
#                                             text_url      character_name  \
# 0   https://www.gutenberg.org/ebooks/70121.txt.utf-8           Graziella
# 1   https://www.gutenberg.org/ebooks/70121.txt.utf-8           Sertanejo
# 2   https://www.gutenberg.org/ebooks/70121.txt.utf-8           Sertanejo
# 3   https://www.gutenberg.org/ebooks/70121.txt.utf-8           Sertanejo
# 4   https://www.gutenberg.org/ebooks/70121.txt.utf-8           Sertanejo
# 5   https://www.gutenberg.org/ebooks/70121.txt.utf-8           Sertanejo
# 6   https://www.gutenberg.org/ebooks/70121.txt.utf-8           Sertanejo
# 7   https://www.gutenberg.org/ebooks/35073.txt.utf-8      Maria do Carmo
# 8   https://www.gutenberg.org/ebooks/35073.txt.utf-8      Maria do Carmo
# 9   https://www.gutenberg.org/ebooks/68807.txt.utf-8  Gervasio Vila-Nova
# 10  https://www.gutenberg.org/ebooks/68807.txt.utf-8  Gervasio Vila-Nova
# 11  https://www.gutenberg.org/ebooks/68807.txt.utf-8  Gervasio Vila-Nova
# 12  https://www.gutenberg.org/ebooks/68807.txt.utf-8  Gervasio Vila-Nova
# 13  https://www.gutenberg.org/ebooks/68807.txt.utf-8  Gervasio Vila-Nova
# 14  https://www.gutenberg.org/ebooks/68807.txt.utf-8  Gervasio Vila-Nova
# 15  https://www.gutenberg.org/ebooks/68807.txt.utf-8  Gervasio Vila-Nova
# 16  https://www.gutenberg.org/ebooks/68807.txt.utf-8  Gervasio Vila-Nova
# 17  https://www.gutenberg.org/ebooks/68807.txt.utf-8               Lucio
# 18  https://www.gutenberg.org/ebooks/68807.txt.utf-8               Lucio
# 19  https://www.gutenberg.org/ebooks/68807.txt.utf-8               Lucio
#
#                                      character_resume  \
# 0   Graziella é uma professora italiana, inicialme...
# 1   Sertanejo é um homem vaidoso, orgulhoso e arro...
# 2   Sertanejo é um homem vaidoso, orgulhoso e arro...
# 3   Sertanejo é um homem vaidoso, orgulhoso e arro...
# 4   Sertanejo é um homem vaidoso, orgulhoso e arro...
# 5   Sertanejo é um homem vaidoso, orgulhoso e arro...
# 6   Sertanejo é um homem vaidoso, orgulhoso e arro...
# 7   Maria do Carmo é uma mulher de trinta anos, ca...
# 8   Maria do Carmo é uma mulher de trinta anos, ca...
# 9   Gervasio Vila-Nova é um artista enigmático e f...
# 10  Gervasio Vila-Nova é um artista enigmático e f...
# 11  Gervasio Vila-Nova é um artista enigmático e f...
# 12  Gervasio Vila-Nova é um artista enigmático e f...
# 13  Gervasio Vila-Nova é um artista enigmático e f...
# 14  Gervasio Vila-Nova é um artista enigmático e f...
# 15  Gervasio Vila-Nova é um artista enigmático e f...
# 16  Gervasio Vila-Nova é um artista enigmático e f...
# 17  Lucio é o narrador, um amigo de Gervasio. Ele ...
# 18  Lucio é o narrador, um amigo de Gervasio. Ele ...
# 19  Lucio é o narrador, um amigo de Gervasio. Ele ...
#
#                                               snippet  \
# 0   O conservador, com um gesto nobre, rejeitou; e...
# 1   --Sim, meu tio; tenho aqui. Accendi o charuto ...
# 2   O Rio começava a apparecer-me. A victoria corr...
# 3   A victoria parou. Saltámos e eu, curioso de vê...
# 4   Os rumores deliciavam-me e enterneciam-me--dei...
# 5   Leve, longinquo, soava o sino da parochia, ora...
# 6   Que trazia eu que me demonstrasse ter vivido n...
# 7   Maria do Carmo, curvada sobre a meza, folheia ...
# 8   MARIA DO CARMO--trinta annos, com dez de casam...
# 9   Por 1895, não sei bem como, achei-me estudando...
# 10  Perturbava o seu aspecto fisico, macerado e es...
# 11  Todo êle encantava as mulheres. Tanta raparigu...
# 12  Entretanto, se o examinavamos com a nossa inte...
# 13  Era uma das _scies_ de Gervasio Vila-Nova: Elo...
# 14  Ah! como era bem diferente, bem mais expontane...
# 15  Aliás, ainda hoje ignoro se o meu amigo era ou...
# 16  Entretanto, o que mais o prejudicava, era sem ...
# 17  No dia seguinte--uma esplendida tarde de inver...
# 18  A conversa logo se entabolou ultra-civilisada ...
# 19  _Vocês_--note-se em parentese--era todo o mund...
#
#                                                traits
# 0   ["misterioso", "gentil", "inteligente", "pragm...
# 1                                     ["conservador"]
# 2   ["vaidoso", "orgulhoso", "arrogante", "dominad...
# 3                           ["curioso", "observador"]
# 4                                      ["observador"]
# 5                             ["curioso", "corajoso"]
# 6   ["questionador", "determinado", "pragmático", ...
# 7                                       ["arrogante"]
# 8                ["curioso", "misterioso", "maldoso"]
# 9                                      ["misterioso"]
# 10                                     ["misterioso"]
# 11                         ["arrogante", "orgulhoso"]
# 12                                       ["corajoso"]
# 13    ["vaidoso", "impulsivo", "cínico", "arrogante"]
# 14                            ["arrogante", "cínico"]
# 15                                     ["misterioso"]
# 16                                     ["negligente"]
# 17                        ["observador", "precavido"]
# 18                                     ["observador"]
# 19                         ["observador", "racional"]

# %%
df = pd.read_csv('characters_dataset.csv')
print(df.shape)
# Out:
# (1536, 10)

# %% [markdown]
# Na primeira versão estável do projeto, foi gerado um CSV contendo 1.546 itens, utilizado para treinar um modelo de classificação baseado nos `traits` definidos previamente. Como etapa adicional de validação, seria interessante verificar se todas as possibilidades de traits especificadas no conjunto geral (enviado à LLM) estão representadas no dataset.

# %%
os.makedirs("/content/data", exist_ok=True)

TRAITS_CSV_PATH = "characters_dataset.csv"
MODEL_PATH = "data/traits_pipeline.joblib"
LABELS_PATH = "data/traits_labels.json"
THRESH_PATH = "data/traits_thresholds.npy"

# %%
def parse_traits_cell(cell):
    if cell is None or str(cell).strip() == "":
        return []
    s = str(cell).strip()
    try:
        parsed = ast.literal_eval(s)
        if isinstance(parsed, (list,tuple)):
            return [str(x).strip() for x in parsed if str(x).strip()]
    except Exception:
        for sep in [";", ",", "|", "/"]:
            if sep in s:
                parts = [p.strip() for p in s.split(sep) if p.strip()]
                if parts:
                    return parts
    return [s]

df['trait_list'] = df['traits'].apply(parse_traits_cell)
df = df[df["snippet"].str.strip() != ""].copy()
print("Linhas após remover snippets vazios:", len(df))
display(df.head(20)['traits'])
# Out:
# Linhas após remover snippets vazios: 1536
# 0     ["misterioso", "gentil", "inteligente", "pragm...
# 1                                       ["conservador"]
# 2     ["vaidoso", "orgulhoso", "arrogante", "dominad...
# 3                             ["curioso", "observador"]
# 4                                        ["observador"]
# 5                               ["curioso", "corajoso"]
# 6     ["questionador", "determinado", "pragmático", ...
# 7                                         ["arrogante"]
# 8                  ["curioso", "misterioso", "maldoso"]
# 9                                        ["misterioso"]
# 10                                       ["misterioso"]
# 11                           ["arrogante", "orgulhoso"]
# 12                                         ["corajoso"]
# 13      ["vaidoso", "impulsivo", "cínico", "arrogante"]
# 14                              ["arrogante", "cínico"]
# 15                                       ["misterioso"]
# 16                                       ["negligente"]
# 17                          ["observador", "precavido"]
# 18                                       ["observador"]
# 19                           ["observador", "racional"]
# Name: traits, dtype: object

# %% [markdown]
# Agora que temos um conjunto de dados, podemos buscar alguns dos personagens da literatura e verificar os `traits` de acordo com suas histórias. Vamos dar uma olhada nos traços de personalidade de João Romão, o proprietário do cortiço, obra de Eça de Queiroz e um grande clássico da literatura.

# %%
def show_examples(name, n=3):
  sub = df[df['character_name'].str.contains(name, case = False, na = False )]
  display(sub[["character_name","snippet","traits"]].head(n))

show_examples("João Romão")
# Out:
#     character_name                                            snippet  \
# 831     João Romão  João Romão foi, dos treze aos vinte e cinco an...
# 832     João Romão  Proprietario e estabelecido por sua conta, o r...
# 833     João Romão  João Romão mostrou grande interesse por esta d...
#
#                                                 traits
# 831                        ["trabalhador", "prudente"]
# 832  ["ambicioso", "determinado", "trabalhador", "r...
# 833                           ["astuto", "calculista"]

# %% [markdown]
# Para aproveitar esses dados, uma abordagem econômica para categorizar o corpus, agora que dispomos de um dataset consistente, é construir um modelo de classificação: separar os conjuntos de treino e teste, treinar e validar o modelo para avaliar seu desempenho e, em seguida, executar uma prova de conceito.

# %%
model_df = df[["snippet","traits"]]
model_df.head()
# Out:
#                                              snippet  \
# 0  O conservador, com um gesto nobre, rejeitou; e...
# 1  --Sim, meu tio; tenho aqui. Accendi o charuto ...
# 2  O Rio começava a apparecer-me. A victoria corr...
# 3  A victoria parou. Saltámos e eu, curioso de vê...
# 4  Os rumores deliciavam-me e enterneciam-me--dei...
#
#                                               traits
# 0  ["misterioso", "gentil", "inteligente", "pragm...
# 1                                    ["conservador"]
# 2  ["vaidoso", "orgulhoso", "arrogante", "dominad...
# 3                          ["curioso", "observador"]
# 4                                     ["observador"]

# %% [markdown]
# ##### Treinamento

# %% [markdown]
# Para o treinamento, define-se uma lista de traços (TRAITS_FULL) usada como classes para um MultiLabelBinarizer, que transforma a coluna trait_list do DataFrame em uma matriz binária Y; em seguida preparam‑se os textos de entrada X a partir da coluna snippet (removendo espaços e com opção de concatenar summaries), convertem‑se esses textos para a lista X_texts e exibem‑se o número e os nomes das labels e alguns exemplos de X/Y para verificação.

# %%
# preparar X (snippet) e Y (multilabel)
TRAITS_FULL = [
    "astuto","inteligente","misterioso","impulsivo","determinado",
    "corajoso","leal","observador","protetor","curioso",
    "arrogante","orgulhoso","cínico","vaidoso","ambicioso",
    "teimoso","dominador","controlador","inflexível","desconfiado",
    "gentil","bondoso","generoso","altruísta","empático",
    "frio","calculista","rígido","prudente","precavido",
    "racional","sarcástico","irônico","questionador","criativo",
    "trabalhador","resiliente","responsável","conservador","pragmático",
    "agressivo","hostil","vingativo","cruel","mentiroso",
    "covarde","irresponsável","negligente","egoísta","maldoso"
]

mlb = MultiLabelBinarizer(classes=TRAITS_FULL)

Y = mlb.fit_transform(df["trait_list"])
print("Labels (n):", len(mlb.classes_))
print("Labels:", mlb.classes_[0:30])

# X: usar snippet (pode concatenar summaries se quiser)
df["text_for_model"] = df["snippet"].astype(str).str.strip()
X_texts = df["text_for_model"].tolist()

print("Exemplos X/Y:", X_texts[:2], Y.shape)
# Out:
# Labels (n): 50
# Labels: ['astuto' 'inteligente' 'misterioso' 'impulsivo' 'determinado' 'corajoso'
#  'leal' 'observador' 'protetor' 'curioso' 'arrogante' 'orgulhoso' 'cínico'
#  'vaidoso' 'ambicioso' 'teimoso' 'dominador' 'controlador' 'inflexível'
#  'desconfiado' 'gentil' 'bondoso' 'generoso' 'altruísta' 'empático' 'frio'
#  'calculista' 'rígido' 'prudente' 'precavido']
# Exemplos X/Y: ['O conservador, com um gesto nobre, rejeitou; eu rejeitei; e uma mocinha\ntriste, que vinha derreada, a olhar melancolicamente a paisagem, como\nse por ali lhe ficassem pedaços do coração, teve um sorriso adoravel,\nrejeitando, por sua vez. Seus olhos castanhos, entre grandes cilios,\nalumiaram-me, e travámos palestra, em tom subtil e discreto, vindo eu\na saber, pelo cicio dos seus labios, que era professora em Sabará,\nna fazenda de um tal Souza Gordo. E disse-me a sua patria--a Italia,\ne o seu nome, já celebre no idyllio--Graziella. E eu, a ouvir-lhe as\nsuaves palavras, via as arvores passarem vertiginosamente, como se\nos campos e os montes assustados fugissem diante do comboio rapido.\nEmquanto andámos, não lhe percebi um movimento, um olhar que não\nfossem do mais candido recato. Lia--um livrinho minusculo, capa de\npercaline roxa e letras de ouro. Em Juiz de Fóra, offerecendo-lhe uma\ncorbelha de figos, aproveitei a sua distracção para surprender o nome\ndo poeta favorito--Leopardi. Era pessimista com tão angelico sorriso!\nAmargo seculo em que as deusas trazem philtros no bolso e seguem a\nseita sombria dos desesperados. Era, de certo, a idéa da morte que\nlhe punha nos serenos olhos tanta melancolia. Na Barra, porém, tive\numa surpresa--voltando ao wagon, encontrei-a sem luvas, o véusinho\nlevantado, trincando, com voracidade, uma côxa de frango. Corou ao\nver-me, mas a fome venceu-a; e, até Mendes, fartou-se regaladamente,\nescorropichando, por uma calha de papel, a farofia de manteiga e ovo.', '--Sim, meu tio; tenho aqui. Accendi o charuto e baforei para o mar a\nprimeira fumaça dando as primicias do meu havana ao respeito, como os\nantigos pastores offereciam a Deus as primicias dos seus rebanhos,\ndepois recostei-me, fumando ante as barbas grisalhas do irmão de meu\npai.'] (1536, 50)
# /usr/local/lib/python3.12/dist-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['agil', 'cioso', 'determinada', 'honesto', 'humilde', 'irascível', 'modesto', 'paciente', 'sensível', 'sincero', 'sério'] will be ignored
#   warnings.warn(

# %% [markdown]
# Após isso, divide-se o conjunto em treino e teste com train_test_split (20% para teste), constrói-se um Pipeline com TfidfVectorizer e OneVsRestClassifier (baseado em LogisticRegression), treina-se com pipeline.fit(X_train, Y_train), persiste-se o pipeline com joblib.dump em MODEL_PATH, salva-se a lista de labels em LABELS_PATH via json.dump e exibem-se mensagens de confirmação

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_texts, Y, test_size=0.20, random_state=42, shuffle=True)

pipeline = Pipeline([
    ("tfidf", TfidfVectorizer(max_features=30000, ngram_range=(1,2), min_df=2)),
    ("clf", OneVsRestClassifier(LogisticRegression(max_iter=2000), n_jobs=-1))
])

pipeline.fit(X_train, Y_train)

joblib.dump(pipeline, MODEL_PATH)
with open(LABELS_PATH, "w", encoding="utf-8") as f:
    json.dump(mlb.classes_.tolist(), f, ensure_ascii=False, indent=2)
print("Modelo salvo em:", MODEL_PATH)
print("Labels salvos em:", LABELS_PATH)
# Out:
# Modelo salvo em: data/traits_pipeline.joblib
# Labels salvos em: data/traits_labels.json

# %%
probs = pipeline.predict_proba(X_test)

# avaliação com threshold 0.5
preds_05 = (probs >= 0.5).astype(int)
print("Hamming loss (0.5):", hamming_loss(Y_test, preds_05))
print("Micro F1 (0.5):", f1_score(Y_test, preds_05, average="micro"))
print("Macro F1 (0.5):", f1_score(Y_test, preds_05, average="macro"))

best_thresh = []
for i in range(Y_test.shape[1]):
    y_true = Y_test[:, i]
    y_score = probs[:, i]
    if y_true.sum() == 0:
        best_thresh.append(0.5)
        continue
    prec, rec, thr = precision_recall_curve(y_true, y_score)
    f1s = 2 * prec * rec / (prec + rec + 1e-12)
    if len(thr) == 0:
        best_thresh.append(0.5)
    else:
        best_thresh.append(float(thr[np.nanargmax(f1s)]))
best_thresh = np.array(best_thresh)
np.save(THRESH_PATH, best_thresh)
print("Thresholds salvos em:", THRESH_PATH)


preds_opt = (probs >= best_thresh[None, :]).astype(int)
print("Hamming loss (opt):", hamming_loss(Y_test, preds_opt))
print("Micro F1 (opt):", f1_score(Y_test, preds_opt, average="micro"))
print("Macro F1 (opt):", f1_score(Y_test, preds_opt, average="macro"))

# relatório
report = classification_report(Y_test, preds_opt, target_names=mlb.classes_, zero_division=0)
print(report)
# Out:
# Hamming loss (0.5): 0.05948051948051948
# Micro F1 (0.5): 0.0
# Macro F1 (0.5): 0.0
# Thresholds salvos em: data/traits_thresholds.npy
# Hamming loss (opt): 0.09201298701298702
# Micro F1 (opt): 0.3491042719338539
# Macro F1 (opt): 0.3437667907190397
#                precision    recall  f1-score   support
#
#        astuto       0.79      0.32      0.46        34
#   inteligente       0.60      0.38      0.46        40
#    misterioso       0.24      0.60      0.34        35
#     impulsivo       0.42      0.50      0.46        26
#   determinado       0.40      0.53      0.46        64
#      corajoso       0.36      0.24      0.29        17
#          leal       0.20      0.38      0.26        21
#    observador       0.32      0.50      0.39        42
#      protetor       0.45      0.53      0.49        19
#       curioso       0.18      0.55      0.27        31
#     arrogante       0.19      0.40      0.26        10
#     orgulhoso       0.52      0.44      0.47        32
#        cínico       0.21      0.21      0.21        14
#       vaidoso       0.33      0.54      0.41        24
#     ambicioso       0.19      0.19      0.19        16
#       teimoso       0.75      0.14      0.24        21
#     dominador       0.60      0.46      0.52        13
#   controlador       0.67      0.27      0.39        22
#    inflexível       0.33      0.44      0.38        18
#   desconfiado       0.33      0.60      0.43         5
#        gentil       0.15      0.75      0.25        28
#       bondoso       0.43      0.27      0.33        22
#      generoso       0.15      0.29      0.20         7
#     altruísta       0.12      0.60      0.20         5
#      empático       0.38      0.40      0.39        15
#          frio       0.19      0.38      0.25         8
#    calculista       0.62      0.31      0.41        26
#        rígido       0.60      0.43      0.50         7
#      prudente       0.80      0.22      0.35        18
#     precavido       0.17      0.47      0.25        15
#      racional       0.30      0.49      0.37        35
#    sarcástico       1.00      0.18      0.31        11
#       irônico       0.60      0.30      0.40        10
#  questionador       0.33      0.54      0.41        13
#      criativo       0.38      0.27      0.32        11
#   trabalhador       0.67      0.40      0.50        25
#    resiliente       0.62      0.25      0.36        20
#   responsável       0.29      0.40      0.34        25
#   conservador       1.00      0.20      0.33         5
#    pragmático       0.24      0.42      0.31        33
#     agressivo       0.57      0.53      0.55        15
#        hostil       0.67      0.33      0.44         6
#     vingativo       1.00      0.20      0.33         5
#         cruel       0.09      0.40      0.15         5
#     mentiroso       1.00      0.14      0.25         7
#       covarde       0.29      0.62      0.40         8
# irresponsável       1.00      0.17      0.29         6
#    negligente       0.03      0.50      0.06         2
#       egoísta       0.32      0.40      0.35        15
#       maldoso       0.20      0.25      0.22         4
#
#     micro avg       0.30      0.41      0.35       916
#     macro avg       0.45      0.39      0.34       916
#  weighted avg       0.43      0.41      0.37       916
#   samples avg       0.30      0.42      0.31       916

# %% [markdown]
# O modelo nao se mostra bom o suficiente pelas F1: com threshold 0.5 tanto Micro quanto Macro F1 são 0.0, ou seja, não há previsões positivas úteis; o Hamming loss baixo (0.059) é enganoso em dados muito desbalanceados. As causas parecem ser ferramentas pouco adaptadas ao português (tokenização, stopwords, lematização, NER) e a escassez de textos em português na API, que aumentam a esparsidade do TF-IDF e o desequilíbrio de classes. A solução prevista é enriquecer os dados com corpus sintético e textos da cultura popular em português para ampliar vocabulário e nomes, balancear classes e melhorar F1 e recall.

# %%
df_extra = pd.read_csv('traits_dataset_50x200.csv')
#df_extra = df_extra.rename(columns={"trait": "traits"}) Se eu errei, Checar
# Concatenar
df_final = pd.concat([df_extra, model_df], ignore_index=True)

if "text_for_model" in df_final.columns and "snippet" not in df_final.columns:
    df_final = df_final.rename(columns={"text_for_model": "snippet"})
if "trait" in df_final.columns and "traits" not in df_final.columns:
    df_final = df_final.rename(columns={"trait": "traits"})

df_final = df_final.dropna(subset=["snippet", "traits"]).copy()
df_final["snippet"] = df_final["snippet"].astype(str).str.strip()

df_final["trait_list"] = df_final["traits"].apply(parse_traits_cell)

# %%
df_final.head()
# Out:
#                                              snippet  traits trait_list
# 0  A person marked by astuto moved through the sc...  astuto   [astuto]
# 1  A person marked by astuto moved through the sc...  astuto   [astuto]
# 2  A person marked by astuto moved through the sc...  astuto   [astuto]
# 3  People often described them as astuto and it s...  astuto   [astuto]
# 4  Known for being astuto, this figure did not he...  astuto   [astuto]

# %%
df_final["snippet_clean"] = df_final["snippet"].astype(str).apply(_normalize_text)

# %% [markdown]
# Após o enriquecimento dos dados, o conjunto foi dividido em 80% para treino e 20% para teste. O modelo foi treinado usando um Pipeline que executa duas etapas principais:
# - tfidf: Converte o texto em vetores numéricos usando TF-IDF, extraindo tanto palavras individuais quanto pares de palavras consecutivas (unigramas e bigramas, com ngram_range=(1,2)).
# - clf: Aplica um classificador OneVsRestClassifier que treina um modelo LogisticRegression para cada classe. Cada um desses modelos é calibrado com CalibratedClassifierCV para que suas previsões representem probabilidades confiáveis.

# %%
base = LogisticRegression(max_iter=2000)

calibrated_lr = CalibratedClassifierCV(
    estimator=base,
    method="sigmoid",
    cv=2
)

clf = OneVsRestClassifier(calibrated_lr, n_jobs=-1)


X_texts2 = df_final["snippet_clean"].astype(str).tolist()
Y_list2 = df_final["trait_list"].tolist()

print("len(X_texts2):", len(X_texts2))
print("len(Y_list2):", len(Y_list2))

#use_classes = True
#mlb2 = MultiLabelBinarizer(classes=TRAITS_FULL)
use_classes = False
mlb2 = MultiLabelBinarizer(classes=TRAITS_FULL)

Y2 = mlb2.fit_transform(Y_list2)

print("Y2.shape:", Y2.shape)
print("Labels (n):", len(mlb2.classes_))

assert len(X_texts2) == Y2.shape[0], f"Inconsistência de tamanhos: len(X_texts2)={len(X_texts2)} vs Y2.shape[0]={Y2.shape[0]}"
print("Shapes consistentes. Y2.shape:", Y2.shape)


X_train2, X_test2, Y_train2, Y_test2 = train_test_split(
    X_texts2, Y2, test_size=0.20, random_state=42, shuffle=True
)

pipeline_2 = Pipeline([
    ("tfidf", TfidfVectorizer(max_features=30000, ngram_range=(1,2), min_df=2)),
    ("clf", OneVsRestClassifier(
                CalibratedClassifierCV(
                    estimator=LogisticRegression(max_iter=2000),
                    method="sigmoid",
                    cv=3
                ),
                n_jobs=-1
            )
    )
])

print("Treinando...")
pipeline_2.fit(X_train2, Y_train2)
print("Treino concluído.")

MODEL_PATH = "modelo_traits.joblib"
LABELS_PATH = "traits_labels.json"

joblib.dump(pipeline_2, MODEL_PATH)
with open(LABELS_PATH, "w", encoding="utf-8") as f:
    json.dump(mlb2.classes_.tolist(), f, ensure_ascii=False, indent=2)

print("Modelo salvo em:", MODEL_PATH)
print("Labels salvos em:", LABELS_PATH)
print("Tamanho treino:", len(X_train2), "tamanho teste:", len(X_test2))
# Out:
# len(X_texts2): 11536
# len(Y_list2): 11536
# Y2.shape: (11536, 50)
# Labels (n): 50
# Shapes consistentes. Y2.shape: (11536, 50)
# Treinando...
# /usr/local/lib/python3.12/dist-packages/sklearn/preprocessing/_label.py:909: UserWarning: unknown class(es) ['agil', 'cioso', 'determinada', 'honesto', 'humilde', 'irascível', 'modesto', 'paciente', 'sensível', 'sincero', 'sério'] will be ignored
#   warnings.warn(
# Treino concluído.
# Modelo salvo em: modelo_traits.joblib
# Labels salvos em: traits_labels.json
# Tamanho treino: 9228 tamanho teste: 2308

# %%
df_final.head()
# Out:
#                                              snippet  \
# 0  O conservador, com um gesto nobre, rejeitou; e...
# 1  --Sim, meu tio; tenho aqui. Accendi o charuto ...
# 2  O Rio começava a apparecer-me. A victoria corr...
# 3  A victoria parou. Saltámos e eu, curioso de vê...
# 4  Os rumores deliciavam-me e enterneciam-me--dei...
#
#                                               traits  \
# 0  ["misterioso", "gentil", "inteligente", "pragm...
# 1                                    ["conservador"]
# 2  ["vaidoso", "orgulhoso", "arrogante", "dominad...
# 3                          ["curioso", "observador"]
# 4                                     ["observador"]
#
#                                           trait_list  \
# 0  [misterioso, gentil, inteligente, pragmático, ...
# 1                                      [conservador]
# 2         [vaidoso, orgulhoso, arrogante, dominador]
# 3                              [curioso, observador]
# 4                                       [observador]
#
#                                        snippet_clean
# 0  conservador gesto nobre rejeitou rejeitei moci...
# 1  sim tio aqui accendi charuto baforei mar prime...
# 2  rio comecava apparecer victoria corria cruzand...
# 3  victoria parou saltamos curioso ver admirar ma...
# 4  rumores deliciavam enterneciam deixei tempo ou...

# %% [markdown]
# Com o modelo retreinado, seu desempenho foi avaliado no conjunto de teste. A otimização dos thresholds por classe elevou o F1-Score Macro para 0.79, indicando um desempenho melhor na classificação das diferentes categorias. Com base nesses resultados, o modelo foi considerado pronto para uso.

# %%
probs2 = pipeline_2.predict_proba(X_test2)  # shape: (n_samples, n_classes)

assert probs2.shape[0] == Y_test2.shape[0], f"n_samples mismatch: probs {probs2.shape[0]} vs Y_test2 {Y_test2.shape[0]}"
assert probs2.shape[1] == Y_test2.shape[1], f"n_classes mismatch: probs {probs2.shape[1]} vs Y_test2 {Y_test2.shape[1]}"

preds_05 = (probs2 >= 0.5).astype(int)
print("Hamming loss (0.5):", hamming_loss(Y_test2, preds_05))
print("Micro F1 (0.5):", f1_score(Y_test2, preds_05, average="micro", zero_division=0))
print("Macro F1 (0.5):", f1_score(Y_test2, preds_05, average="macro", zero_division=0))

best_thresh = []
for i in range(Y_test2.shape[1]):
    y_true = Y_test2[:, i]
    y_score = probs2[:, i]
    # se não houver positivos verdadeiros, fallback para 0.5
    if y_true.sum() == 0:
        best_thresh.append(0.5)
        continue
    prec, rec, thr = precision_recall_curve(y_true, y_score)
    f1s = 2 * prec * rec / (prec + rec + 1e-12)
    if len(thr) == 0:
        best_thresh.append(0.5)
    else:
        best_thresh.append(float(thr[np.nanargmax(f1s)]))

best_thresh = np.array(best_thresh)
np.save(THRESH_PATH, best_thresh)
print("Thresholds salvos em:", THRESH_PATH)

preds_opt = (probs2 >= best_thresh[None, :]).astype(int)
print("Hamming loss (opt):", hamming_loss(Y_test2, preds_opt))
print("Micro F1 (opt):", f1_score(Y_test2, preds_opt, average="micro", zero_division=0))
print("Macro F1 (opt):", f1_score(Y_test2, preds_opt, average="macro", zero_division=0))
# Out:
# Hamming loss (0.5): 0.010641247833622183
# Micro F1 (0.5): 0.7456503728251864
# Macro F1 (0.5): 0.7518192672068367
# Thresholds salvos em: data/traits_thresholds.npy
# Hamming loss (opt): 0.013336221837088389
# Micro F1 (opt): 0.740253164556962
# Macro F1 (opt): 0.7982333589065864

# %%
report = classification_report(Y_test2, preds_opt, target_names=mlb.classes_, zero_division=0)
print(report)
# Out:
#                precision    recall  f1-score   support
#
#        astuto       0.77      0.69      0.73        59
#   inteligente       0.42      0.53      0.47        85
#    misterioso       0.72      0.73      0.72        66
#     impulsivo       0.96      0.60      0.74        72
#   determinado       0.28      1.00      0.44        91
#      corajoso       0.96      0.82      0.88        61
#          leal       0.83      0.69      0.75        62
#    observador       0.24      1.00      0.38        82
#      protetor       0.73      0.70      0.72        70
#       curioso       0.67      0.64      0.65        58
#     arrogante       0.91      0.70      0.79        56
#     orgulhoso       0.59      0.71      0.65        70
#        cínico       0.98      0.81      0.88        57
#       vaidoso       0.82      0.67      0.74        55
#     ambicioso       1.00      0.62      0.77        64
#       teimoso       0.93      0.73      0.82        56
#     dominador       0.90      0.69      0.78        55
#   controlador       0.91      0.70      0.79        69
#    inflexível       1.00      0.66      0.80        53
#   desconfiado       1.00      0.90      0.95        39
#        gentil       0.63      0.49      0.55        65
#       bondoso       0.82      0.67      0.74        61
#      generoso       0.97      0.89      0.93        35
#     altruísta       1.00      0.89      0.94        44
#      empático       0.91      0.77      0.83        52
#          frio       0.96      0.80      0.87        55
#    calculista       0.96      0.80      0.87        65
#        rígido       1.00      0.83      0.90        46
#      prudente       0.91      0.64      0.75        50
#     precavido       0.89      0.78      0.83        63
#      racional       0.54      0.61      0.58        72
#    sarcástico       0.95      0.91      0.93        44
#       irônico       0.92      0.86      0.89        42
#  questionador       1.00      0.82      0.90        49
#      criativo       0.98      0.91      0.95        58
#   trabalhador       0.72      0.85      0.78        55
#    resiliente       0.86      0.83      0.85        66
#   responsável       0.73      0.45      0.56        67
#   conservador       1.00      0.82      0.90        67
#    pragmático       0.76      0.62      0.68        63
#     agressivo       0.96      0.82      0.88        60
#        hostil       1.00      0.84      0.91        44
#     vingativo       1.00      0.92      0.96        36
#         cruel       1.00      0.96      0.98        50
#     mentiroso       1.00      0.95      0.97        40
#       covarde       1.00      0.90      0.95        50
# irresponsável       0.96      0.87      0.91        52
#    negligente       1.00      0.89      0.94        44
#       egoísta       0.87      0.68      0.77        60
#       maldoso       1.00      0.93      0.97        46
#
#     micro avg       0.72      0.76      0.74      2881
#     macro avg       0.86      0.77      0.80      2881
#  weighted avg       0.83      0.76      0.77      2881
#   samples avg       0.85      0.86      0.85      2881

# %% [markdown]
# ##### Prova de Conceito
#
# Para uma prova de conceito, realizou-se uma validação qualitativa do modelo utilizando trechos de livros da série 'Os Karas'. Os personagens desta série possuem perfis bem definidos, o que os torna bons candidatos para uma avaliação manual das previsões.

# %%
def predict_traits_snippet(snippet, max_k=2):
    probs = pipeline_2.predict_proba([snippet])[0]

    try:
        thresh = np.load(THRESH_PATH)
        if len(thresh) != len(mlb.classes_):
            thresh = np.array([0.5] * len(mlb.classes_))
    except:
        thresh = np.array([0.5] * len(mlb.classes_))


    selected = [(lab, float(p)) for lab, p, t in zip(mlb.classes_, probs, thresh) if p >= t]
    if len(selected) > max_k:
        selected = sorted(selected, key=lambda x: x[1], reverse=True)[:max_k]

    if len(selected) == 0:
        all_sorted = sorted(zip(mlb.classes_, probs), key=lambda x: x[1], reverse=True)
        selected = [(lab, float(p)) for lab, p in all_sorted[:max_k]]

    return {
        "labels": [lab for lab, p in selected],
        "scores": {lab: p for lab, p in selected}
    }

# teste rápido
ex = X_test[30]
print("Snippet exemplo:", ex)
print("Predição:", predict_traits_snippet(ex))
# Out:
# Snippet exemplo: Na sala de visitas a menina Adelaide collocava por suas proprias mãos
# heras e flores em volta das serpentinas.
# Predição: {'labels': ['trabalhador', 'responsável'], 'scores': {'trabalhador': 0.6205194928192599, 'responsável': 0.6090902213674513}}

# %%
variation_dict = {
    "miguel": [
        "Miguel sempre se destacava pela maneira como observava o mundo antes de se mover. "
        "Nada nele era precipitado; tudo parecia seguir um ritmo interno silencioso, disciplinado, quase científico. "
        "Costumava escutar as pessoas com atenção real, anotando mentalmente detalhes que a maioria ignorava: "
        "contradições, hesitações, receios escondidos. No entanto, sua racionalidade nunca significou frieza absoluta. "
        "Pelo contrário — Miguel carregava uma espécie de responsabilidade moral que o obrigava a agir quando percebia "
        "injustiças, principalmente se envolviam alguém mais vulnerável. Era protetor por impulso ético, não por vaidade. "
        "Quando surgia um conflito, sua postura sempre combinava calma e firmeza. Ele podia até estar tremendo por dentro, "
        "desafiadores, Magrí respirava fundo, ajustava a postura e seguia adiante — não para ser admirada, mas porque "
        "acreditava profundamente no que era certo."
    ],

    "calu": [
        "Calu era energia pura. Sua curiosidade parecia infinita e sua imaginação nunca descansava. Era o tipo de pessoa que "
        "via potencial em qualquer situação: um código secreto, uma nova ideia, um plano ousado. Essa impulsividade criativa o "
        "levava tanto a soluções brilhantes quanto a pequenos desastres, mas Calu sempre se recuperava rápido. Para ele, errar "
        "nunca foi um problema — o verdadeiro fracasso era não tentar. Seu entusiasmo tinha uma força curiosa: unia o grupo, "
        "animava os amigos e transformava tensões em risos. Mas por trás da alegria constante havia uma certa insegurança "
        "silenciosa, aquela vontade de ser útil, de ajudar, de fazer parte de algo maior. Calu era generoso mesmo quando "
        "precisava aprender a se organizar melhor; era leal quando todos duvidavam; era a fagulha que acendia a motivação dos "
        "demais. Quando suas ideias davam certo, seu sorriso era sincero — não de orgulho, mas de celebração coletiva."
    ],

    "andrade": [
        "Andrade era um profissional que misturava rigor, paciência e humanidade em doses raras. Seu método era meticuloso: "
        "coletava depoimentos, organizava pistas, revisava documentos com olhar treinado e nunca tomava decisões sem checar "
        "cada detalhe. Porém, sua frieza técnica não anulava seu senso de compaixão; pelo contrário, ele fazia questão de "
        "proteger inocentes e sempre explicava suas decisões com clareza, sem arrogância. Coragem, para Andrade, não era "
        "gritar nem se exibir — era agir quando ninguém mais podia. Em campo, tomava decisões rápidas e seguras, mas no "
        "convívio com os jovens mostrava um lado mentor, paciente, capaz de ensinar com calma e firmeza. Sua ética "
        "profissional era tão sólida quanto sua disposição para admitir incertezas quando elas existiam. Andrade carregava nos "
        "ombros o peso da experiência, mas usava esse peso para abrir caminho para os outros, nunca para se impor."
    ]
}


for name, variations in variation_dict.items():
    print("\n======", name.upper(), "======")
    for t in variations:
        print("\nSnippet:", t)
        print("Pred:", predict_traits_snippet(t))
# Out:
# ====== MIGUEL ======
#
# Snippet: Miguel sempre se destacava pela maneira como observava o mundo antes de se mover. Nada nele era precipitado; tudo parecia seguir um ritmo interno silencioso, disciplinado, quase científico. Costumava escutar as pessoas com atenção real, anotando mentalmente detalhes que a maioria ignorava: contradições, hesitações, receios escondidos. No entanto, sua racionalidade nunca significou frieza absoluta. Pelo contrário — Miguel carregava uma espécie de responsabilidade moral que o obrigava a agir quando percebia injustiças, principalmente se envolviam alguém mais vulnerável. Era protetor por impulso ético, não por vaidade. Quando surgia um conflito, sua postura sempre combinava calma e firmeza. Ele podia até estar tremendo por dentro, mas por fora mantinha o controle, movido pela convicção de que decisões tomadas no calor do medo quase sempre feriam mais do que resolviam. O grupo confiava nele porque Miguel nunca fugia das responsabilidades difíceis. Às vezes ele parecia distante — não por arrogância, mas porque carregava sozinho o peso de pensar três passos à frente. Sua coragem não era barulhenta: era feita de escolhas difíceis, assumidas com serenidade e lealdade absoluta aos amigos.
# Pred: {'labels': ['protetor', 'determinado'], 'scores': {'protetor': 0.7141908960625957, 'determinado': 0.2183861662956591}}
#
# ====== CALU ======
#
# Snippet: Calu era energia pura. Sua curiosidade parecia infinita e sua imaginação nunca descansava. Era o tipo de pessoa que via potencial em qualquer situação: um código secreto, uma nova ideia, um plano ousado. Essa impulsividade criativa o levava tanto a soluções brilhantes quanto a pequenos desastres, mas Calu sempre se recuperava rápido. Para ele, errar nunca foi um problema — o verdadeiro fracasso era não tentar. Seu entusiasmo tinha uma força curiosa: unia o grupo, animava os amigos e transformava tensões em risos. Mas por trás da alegria constante havia uma certa insegurança silenciosa, aquela vontade de ser útil, de ajudar, de fazer parte de algo maior. Calu era generoso mesmo quando precisava aprender a se organizar melhor; era leal quando todos duvidavam; era a fagulha que acendia a motivação dos demais. Quando suas ideias davam certo, seu sorriso era sincero — não de orgulho, mas de celebração coletiva.
# Pred: {'labels': ['leal', 'generoso'], 'scores': {'leal': 0.9409985173406467, 'generoso': 0.7404776103771122}}
#
# ====== ANDRADE ======
#
# Snippet: Andrade era um profissional que misturava rigor, paciência e humanidade em doses raras. Seu método era meticuloso: coletava depoimentos, organizava pistas, revisava documentos com olhar treinado e nunca tomava decisões sem checar cada detalhe. Porém, sua frieza técnica não anulava seu senso de compaixão; pelo contrário, ele fazia questão de proteger inocentes e sempre explicava suas decisões com clareza, sem arrogância. Coragem, para Andrade, não era gritar nem se exibir — era agir quando ninguém mais podia. Em campo, tomava decisões rápidas e seguras, mas no convívio com os jovens mostrava um lado mentor, paciente, capaz de ensinar com calma e firmeza. Sua ética profissional era tão sólida quanto sua disposição para admitir incertezas quando elas existiam. Andrade carregava nos ombros o peso da experiência, mas usava esse peso para abrir caminho para os outros, nunca para se impor.
# Pred: {'labels': ['determinado', 'observador'], 'scores': {'determinado': 0.2780236319951838, 'observador': 0.13207066825160185}}

# %% [markdown]
# #### Pontos de melhoria ou atenção
#
# * O processo como um todo não é idempotente: se rodarmos o pipeline N vezes, poderemos obter N respostas diferentes para a mesma entrada.
#
# * O processo não é resiliente: em caso de erro, não conseguimos retomar automaticamente do ponto em que paramos, o que pode gerar deduplicação de dados e reprocessamento desnecessário. Ainda há mascaramento de erros genéricos, se algo falhar, a iteração é ignorada, mas se for um erro em cadeia, por exemplo, erro de API KEY para a LLM, ele tentará para todas as iterações.
#
# * Para cada personagem, fazemos uma nova requisição à API que fornece o livro em formato de texto, o que pode ser considerado um uso excessivo de recursos do site se executado com muita frequência.
#
# * É necessário definir estratégias para contornar a classificação equivocada de nomes próprios, melhorando o `output` ao juntar variações que se referem à mesma pessoa (por exemplo, “Luiz” e “Luiz da Silva”). Uma possibilidade seria envolver a LLM nesse processo de normalização e agrupamento, mas ainda é preciso estabelecer critérios sobre o que deve ou não ser enviado para esse passo.

# %% [markdown]
# #### Interface
#
# Com o modelo finalizado, foi desenvolvida uma interface que permite ao usuário submeter trechos de livros e visualizar as duas características de personalidade mais prováveis do personagem analisado. O repositório do projeto está disponível em https://github.com/jeniferss/MCCC008-23_IA e a aplicação pode ser acessada em https://mccc008-23ia-production.up.railway.app/.
